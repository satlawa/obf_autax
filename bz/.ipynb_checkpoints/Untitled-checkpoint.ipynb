# %%
import os
import numpy as np
import pandas as pd
import re

# %%
#home directory
home_path = os.getcwd()[:os.getcwd().find('Code/python/obf_autax/bz')-1]
# set bz_path
nutz_path = os.path.join(home_path, 'Data', 'obf_autax', 'haselbach', 'nutz_171_11_ps_200907x.xlsx')
ekl_path = os.path.join(home_path, 'Data', 'obf_autax', 'haselbach', 'ekl_TO1310_11.xlsx')


print(home_path)
print(nutz_path)
print(ekl_path)
# Out:
# /home/philipp
# /home/philipp/Data/obf_autax/haselbach/nutz_171_11_ps_200907x.xlsx
# /home/philipp/Data/obf_autax/haselbach/ekl_TO1310_11.xlsx

# %%
nutz_data = pd.read_excel(nutz_path)
ekl_data = pd.read_excel(ekl_path)

# %%
nutz_data.head()
# Out:
#       WO  S  MA  FL     LH   NH  SUM   DR   BH   ZP   SG    RU  \
# 0  298C0  1  DF   0   60.0  0.0   60  2.0  1.0  3.0  1.0  31.0
# 1  289F1  1  LI   0  100.0  0.0  100  2.0  1.0  3.0  4.0  35.0
# 2  289H1  1  LI   0   80.0  0.0   80  2.0  1.0  3.0  1.0  31.0
# 3  298I0  1  LI   0  100.0  0.0  100  2.0  1.0  3.0  1.0  36.0
# 4  298K0  1  LI   0   50.0  0.0   50  2.0  1.0  3.0  1.0  31.0
#
#                                   Text    ABT Unnamed: 14 Unnamed: 15
# 0  Anfang - Ende Dezennium, KIeinstock  298C2         NaN         NaN
# 1               Mitte - Ende Dezennium    NaN         NaN         NaN
# 2               Mitte - Ende Dezennium    NaN         NaN         NaN
# 3               Mitte - Ende Dezennium  298I0         NaN         NaN
# 4               Mitte - Ende Dezennium    NaN         NaN         NaN

# %%
ekl_data.head()
# Out:
#    Forstbetrieb.1  Teiloperats-ID.1  Forstrevier  Abteilung Unterabteil.  \
# 0             171              1310           11        298            A
# 1             171              1310           11        298            B
# 2             171              1310           11        298            B
# 3             171              1310           11        298            C
# 4             171              1310           11        298            F
#
#    Teilfl. WE-Typ  Betriebsklasse  Umtriebszeit  Nebengrund Art  ...  \
# 0        0     WO            9010           140             NaN  ...
# 1        1     WO            9010           140             NaN  ...
# 2        2     WO            9010           140             NaN  ...
# 3        0     WO            9010           140             NaN  ...
# 4        1     WO            9010           140             NaN  ...
#
#    LA_ekl.1  KI_ekl.1  SK_ekl.1  Unnamed: 78        BU        FI        TA  \
# 0  7.582800  7.672105  7.295544          NaN  0.793506  0.690685  0.658325
# 1  5.937596  5.307158  5.595558          NaN  0.968473  0.867603  0.856425
# 2  7.123337  7.072292  5.416499          NaN  1.291440  0.972256  0.931850
# 3  7.276538  7.168263  6.036868          NaN  0.934029  0.783129  0.756952
# 4  3.983535  4.338099  5.536367          NaN  1.144945  1.134727  1.159593
#
#          LA        KI        SK
# 0  0.920063  0.733004  0.723859
# 1  1.090541  0.974325  0.858187
# 2  1.289419  1.128225  0.950114
# 3  1.031125  0.860739  0.791599
# 4  1.434996  1.271049  1.111870
#
# [5 rows x 85 columns]

# %%
merge_data = pd.merge(ekl_data, nutz_data, how='outer', on='WO')

# %%
# set raw_path
raw_path = os.path.join(home_path, 'Data', 'obf_autman', 'sources', 'TO_1310_11_roh.XLS')
# read tsv
wo_data = pd.read_csv(raw_path, sep='\t', encoding = "ISO-8859-1", decimal=',', error_bad_lines=False)
# filter relevant data
wo_data = wo_data[wo_data['Best.-Schicht'] == 0]
# Out:
# /home/philipp/miniconda3/envs/autax_rec/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (29,102,103,108,112,113,114,124,126,144,145,146,147,148) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
wo_data.columns[:100]
# Out:
# Index(['Merkmalausprägung', 'AuswKatTyp', 'Teiloperats-ID', 'Forstbetrieb',
#        'Debitor', 'TO-Bezeichnung', 'Status', 'Beg. Laufzeit', 'Ende Laufzeit',
#        'Operat-ID', 'vorgeschl. Hiebssatz', 'Verantwortlicher',
#        'Erfassungsstatus', 'Migriert?', 'GUID', 'Forstbetrieb.1',
#        'Teiloperats-ID.1', 'Forstrevier', 'Abteilung', 'Unterabteil.',
#        'Teilfl.', 'Debitor.1', 'Bearbeitungsblock', 'WE-Typ', 'Betriebsklasse',
#        'Umtriebszeit', 'Nebengrund Art', 'Ertragssituation',
#        'Bewirtschaftungsform', 'Schutzwaldkategorie', 'Fläche in HA',
#        'Seehöhe', 'Exposition', 'Neigung', 'Standorteinheit', 'Vegetationstyp',
#        'Waldtyp', 'Wuchsgebiet', 'Überh. Laubholz', 'Überh. Nadelhz.',
#        'fr. Schälschade', 'Verbissgrad', 'SchutzwaldProjNr', 'Schlussgrad',
#        'Stabilität', 'VJ Bedingung', 'VJ Situation', 'Erreichbark. des BZ',
#        'Selektiver Verbiss', 'Erfassungsstatus.1', 'Storno', 'Angelegt von',
#        'Angelegt am', 'Uhrzeit', 'Geändert von', 'Geändert am', 'Uhrzeit.1',
#        'Waldort', 'GUID.1', 'GUID.2', 'Forstbetrieb.2', 'Teiloperats-ID.2',
#        'Forstrevier.1', 'Abteilung.1', 'Unterabteil..1', 'Teilfl..1',
#        'Best.-Schicht', 'Debitor.2', 'Schichtanteil', 'Schichtalter',
#        'S-Best.grad', 'Erfassungsstatus.2', 'Storno.1', 'GUID.3', 'GUID.4',
#        'Forstbetrieb.3', 'Teiloperats-ID.3', 'Forstrevier.2', 'Abteilung.2',
#        'Unterabteil..2', 'Teilfl..2', 'Best.-Schicht.1', 'Baumart',
#        'Debitor.3', 'Baumartenanteil', 'BaumartenBestockgrad', 'Schälgrad',
#        'Ertragsklasse', 'Vorrat / ha', 'Laubholzvorrat / ha',
#        'Nadelholzvorrat / ha', 'Vorrat am Ort', 'Laubholzvorrat Ort',
#        'Nadelholzvorrat Ort', 'GSOLL / HA', 'GIST / HA', 'lauf. Zuwachs / HA',
#        'DGZU / HA', 'HDZ', 'LGZ'],
#       dtype='object')

# %%
wo_data

# %%
wo_data = wo_data[['Abteilung', 'Unterabteil.','Teilfl.', 'WE-Typ', 'Fläche in HA']]

# %%
wo_data['WO'] = wo_data['Abteilung'].astype(str) + wo_data['Unterabteil.'] + wo_data['Teilfl.'].astype(str)
# Out:
# /home/philipp/miniconda3/envs/autax_rec/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
wo_data
# Out:
#       Abteilung Unterabteil.  Teilfl. WE-Typ  Fläche in HA      WO
# 0           178            4       11     NG          0.03  178411
# 1           178            4       10     NG          0.07  178410
# 2           179            4       10     NG          0.19  179410
# 3           179            4       11     NG          0.45  179411
# 4           182            4       10     NG          0.19  182410
# ...         ...          ...      ...    ...           ...     ...
# 8184        371            L        0     WO          1.55   371L0
# 8193        378            F        3     WO          0.55   378F3
# 8197        378            F        2     WO          0.88   378F2
# 8200        378            F        1     WO          2.06   378F1
# 8205        378            D        0     WO          0.46   378D0
#
# [1561 rows x 6 columns]

# %%
merge_data = pd.merge(merge_data, wo_data, how='outer', on='WO')

# %%
# set bz_path
save_path = os.path.join(home_path, 'Data', 'obf_autax', 'haselbach', 'nutz_1310_171_11_20201105.csv')
merge_data.to_csv(save_path, index=False)

# %%
# set raw_path
raw_path = os.path.join(home_path, 'Data', 'obf_autman', 'sources', 'TO_1310_11_roh.XLS')
# read tsv
v_data = pd.read_csv(raw_path, sep='\t', encoding = "ISO-8859-1", decimal=',', error_bad_lines=False)

v_data
# Out:
# /home/philipp/miniconda3/envs/autax_rec/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (29,102,103,108,112,113,114,124,126,144,145,146,147,148) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       Merkmalausprägung  AuswKatTyp  Teiloperats-ID  Forstbetrieb  Debitor  \
# 0                     0         NaN            1310           171   220442
# 1                     0         NaN            1310           171   220442
# 2                     0         NaN            1310           171   220442
# 3                     0         NaN            1310           171   220442
# 4                     0         NaN            1310           171   220442
# ...                 ...         ...             ...           ...      ...
# 8203                  0         NaN            1310           171   220442
# 8204                  0         NaN            1310           171   220442
# 8205                  0         NaN            1310           171   220442
# 8206                  0         NaN            1310           171   220442
# 8207                  0         NaN            1310           171   220442
#
#      TO-Bezeichnung  Status Beg. Laufzeit Ende Laufzeit  Operat-ID  ...  \
# 0           FE 2020       1    01.01.2021    31.12.2030          0  ...
# 1           FE 2020       1    01.01.2021    31.12.2030          0  ...
# 2           FE 2020       1    01.01.2021    31.12.2030          0  ...
# 3           FE 2020       1    01.01.2021    31.12.2030          0  ...
# 4           FE 2020       1    01.01.2021    31.12.2030          0  ...
# ...             ...     ...           ...           ...        ...  ...
# 8203        FE 2020       1    01.01.2021    31.12.2030          0  ...
# 8204        FE 2020       1    01.01.2021    31.12.2030          0  ...
# 8205        FE 2020       1    01.01.2021    31.12.2030          0  ...
# 8206        FE 2020       1    01.01.2021    31.12.2030          0  ...
# 8207        FE 2020       1    01.01.2021    31.12.2030          0  ...
#
#                                     Zeile1  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 8203                                   NaN
# 8204                                   NaN
# 8205  ST   sanft geneigte Mulde, vergrast,
# 8206                                   NaN
# 8207                                   NaN
#
#                                                  Zeile2 Zeile3  Zeile4 Zeile5  \
# 0                                                   NaN    NaN     NaN    NaN
# 1                                                   NaN    NaN     NaN    NaN
# 2                                                   NaN    NaN     NaN    NaN
# 3                                                   NaN    NaN     NaN    NaN
# 4                                                   NaN    NaN     NaN    NaN
# ...                                                 ...    ...     ...    ...
# 8203                                                NaN    NaN     NaN    NaN
# 8204                                                NaN    NaN     NaN    NaN
# 8205  BE   bedeutender Trockenstandort des Windwurf ...    NaN     NaN    NaN
# 8206                                                NaN    NaN     NaN    NaN
# 8207                                                NaN    NaN     NaN    NaN
#
#       Zeile6  Zeile7  Zeile8  Bestockungsziel Flächenanteil
# 0        NaN     NaN     NaN              NaN           0.0
# 1        NaN     NaN     NaN              NaN           0.0
# 2        NaN     NaN     NaN              NaN           0.0
# 3        NaN     NaN     NaN              NaN           0.0
# 4        NaN     NaN     NaN              NaN           0.0
# ...      ...     ...     ...              ...           ...
# 8203     NaN     NaN     NaN              NaN           0.0
# 8204     NaN     NaN     NaN              NaN           0.0
# 8205     NaN     NaN     NaN      4BU 4LA 2SK           0.0
# 8206     NaN     NaN     NaN              NaN           0.0
# 8207     NaN     NaN     NaN              NaN           0.0
#
# [8208 rows x 152 columns]

# %%
table = pd.pivot_table(v_data, values=['Laubholzvorrat / ha', 'Nadelholzvorrat / ha', 'Vorrat / ha'],\
                       index=['Waldort'], aggfunc=np.sum)
table.reset_index(inplace=True)

# %%
table.columns = ['WO', 'v_LH_ha', 'v_NH_ha', 'v_ha',]

# %%
table.iloc[500:520]
# Out:
#         WO  v_LH_ha  v_NH_ha    v_ha
# 500  312D0    95.17    58.56  153.73
# 501  312E0    53.12   101.60  154.72
# 502  312F0    30.83   227.70  258.53
# 503  312G0   261.56    42.80  304.36
# 504  312H1    54.92   100.80  155.72
# 505  312H2     0.00     0.00    0.00
# 506  312I0    53.16    73.00  126.16
# 507  312K0   251.10    24.74  275.84
# 508  312L0    42.84   279.19  322.03
# 509  312M0    26.28   210.67  236.95
# 510  31341     0.00     0.00    0.00
# 511  313A1   215.71     0.00  215.71
# 512  313A2    53.04    59.84  112.88
# 513  313B0     0.00     0.00    0.00
# 514  313E1   319.94     0.00  319.94
# 515  313E2     0.07     0.00    0.07
# 516  313F0   286.10     0.00  286.10
# 517  313H1    99.30   177.10  276.40
# 518  313H2    16.40    47.96   64.36
# 519  313H3     0.00     0.00    0.00

# %%
# set raw_path
raw_path = os.path.join(home_path, 'Data', 'obf_autax', 'haselbach', 'nutz_1310_171_11_20201105.xlsx')
# read tsv
nutz_data = pd.read_excel(raw_path)

nutz_data.head()
# Out:
#    Forstbetrieb.1  Teiloperats-ID.1  Forstrevier  Abteilung_x Unterabteil._x  \
# 0           171.0            1310.0         11.0        298.0              A
# 1           171.0            1310.0         11.0        298.0              B
# 2           171.0            1310.0         11.0        298.0              B
# 3           171.0            1310.0         11.0        298.0              C
# 4           171.0            1310.0         11.0        298.0              F
#
#    Teilfl._x WE-Typ_x  Betriebsklasse  Umtriebszeit  Nebengrund Art  ...   SG  \
# 0        0.0       WO          9010.0         140.0             NaN  ...  NaN
# 1        1.0       WO          9010.0         140.0             NaN  ...  NaN
# 2        2.0       WO          9010.0         140.0             NaN  ...  NaN
# 3        0.0       WO          9010.0         140.0             NaN  ...  1.0
# 4        1.0       WO          9010.0         140.0             NaN  ...  4.0
#
#      RU                                 Text  Unnamed: 14  Unnamed: 15  \
# 0   NaN                                  NaN          NaN          NaN
# 1   NaN                                  NaN          NaN          NaN
# 2   NaN                                  NaN          NaN          NaN
# 3  31.0  Anfang - Ende Dezennium, KIeinstock          NaN          NaN
# 4  35.0               Mitte - Ende Dezennium          NaN          NaN
#
#   Abteilung_y  Unterabteil._y  Teilfl._y WE-Typ_y  Fläche in HA.1
# 0         298               A          0       WO            1.18
# 1         298               B          1       WO            1.58
# 2         298               B          2       WO            1.12
# 3         298               C          0       WO            1.92
# 4         298               F          1       WO            3.78
#
# [5 rows x 113 columns]

# %%
nutz_data = pd.merge(nutz_data, table, how='left', on='WO')

# %%
nutz_data
# Out:
#       Forstbetrieb.1  Teiloperats-ID.1  Forstrevier  Abteilung_x  \
# 0              171.0            1310.0         11.0        298.0
# 1              171.0            1310.0         11.0        298.0
# 2              171.0            1310.0         11.0        298.0
# 3              171.0            1310.0         11.0        298.0
# 4              171.0            1310.0         11.0        298.0
# ...              ...               ...          ...          ...
# 1560             NaN               NaN          NaN          NaN
# 1561             NaN               NaN          NaN          NaN
# 1562             NaN               NaN          NaN          NaN
# 1563             NaN               NaN          NaN          NaN
# 1564             NaN               NaN          NaN          NaN
#
#      Unterabteil._x  Teilfl._x WE-Typ_x  Betriebsklasse  Umtriebszeit  \
# 0                 A        0.0       WO          9010.0         140.0
# 1                 B        1.0       WO          9010.0         140.0
# 2                 B        2.0       WO          9010.0         140.0
# 3                 C        0.0       WO          9010.0         140.0
# 4                 F        1.0       WO          9010.0         140.0
# ...             ...        ...      ...             ...           ...
# 1560            NaN        NaN      NaN             NaN           NaN
# 1561            NaN        NaN      NaN             NaN           NaN
# 1562            NaN        NaN      NaN             NaN           NaN
# 1563            NaN        NaN      NaN             NaN           NaN
# 1564            NaN        NaN      NaN             NaN           NaN
#
#       Nebengrund Art  ... Unnamed: 14 Unnamed: 15 Abteilung_y  Unterabteil._y  \
# 0                NaN  ...         NaN         NaN         298               A
# 1                NaN  ...         NaN         NaN         298               B
# 2                NaN  ...         NaN         NaN         298               B
# 3                NaN  ...         NaN         NaN         298               C
# 4                NaN  ...         NaN         NaN         298               F
# ...              ...  ...         ...         ...         ...             ...
# 1560             NaN  ...         NaN         NaN         183               B
# 1561             NaN  ...         NaN         NaN         183               C
# 1562             NaN  ...         NaN         NaN         183               F
# 1563             NaN  ...         NaN         NaN         184               K
# 1564             NaN  ...         NaN         NaN         184               L
#
#       Teilfl._y WE-Typ_y  Fläche in HA.1  v_LH_ha v_NH_ha    v_ha
# 0             0       WO            1.18   342.26   13.90  356.16
# 1             1       WO            1.58   257.66   77.29  334.95
# 2             2       WO            1.12    24.40  222.59  246.99
# 3             0       WO            1.92   285.75    0.00  285.75
# 4             1       WO            3.78    54.48  363.92  418.40
# ...         ...      ...             ...      ...     ...     ...
# 1560          2       WO            9.04      NaN     NaN     NaN
# 1561          0       WO            8.10      NaN     NaN     NaN
# 1562          2       WO           11.26      NaN     NaN     NaN
# 1563          0       WO            4.42      NaN     NaN     NaN
# 1564          0       WO            1.80      NaN     NaN     NaN
#
# [1565 rows x 116 columns]

# %%
# set bz_path
save_path = os.path.join(home_path, 'Data', 'obf_autax', 'haselbach', 'nutz_1310_171_11_20201106.csv')
nutz_data.to_csv(save_path, index=False)
