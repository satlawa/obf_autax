# %%
import os
import h5py
import cv2
import numpy as np
import pandas as pd
import sklearn as skl
from matplotlib import pyplot as plt

from pdf2image import convert_from_path, convert_from_bytes
import pytesseract

from OCRVision import OCRVision
from OCRPharse3 import OCRPharse3
from OCRData import OCRData

# %%
# set home directory
home_path = os.getcwd()[:os.getcwd().find('Code/python/obf_autax/ocr')-1]
# set input_path
input_path = os.path.join(home_path, 'Data', 'obf_autman', 'pdf', 'Manuale_Faistenau_20201101.pdf')

# Manuale_Faistenau_20201101
# Manuale_Haselbach_Mannersdorf_20200430

# %%
# convert pdf to image (pdf2image)
def convert_to_image(input_path, page_nr):

    pages = convert_from_path(input_path, 500, first_page=page_nr, last_page=page_nr)

    return pages[0]

# %%
#img = convert_to_image(input_path, 3).convert('RGB')
#img = np.array(img)
# 113

img = convert_to_image(input_path, 720).convert('RGB')
img = np.array(img)

# %%
data = OCRPharse3()

# %%
data.pharse_page(img)
# Out:
# 094 B1

# %%
for i in range(721,953): # 952
    img = convert_to_image(input_path, i).convert('RGB')
    img = np.array(img)
    data.pharse_page(img)
# Out:
# 094 B2
# 094 D1
# 094 D2
# 094 D3
# 094 D4
# 094 D5
# 094 D6
# 094 GO
# 094 I 0
# 094 K 1
# 094 K2
# 094 K 3
# 094 K4
# 094 K5
# 094 K6
#
# 094 L 1
# 094 L2
# 094 M1
# 094 M2
# 094 M3
# 094 MA
# 094 M5
# 095 A 1
# 095 A2
# 095 A3
# 095 A4
# 095 BO
# 095 C 1
# 095 C2
# 095 DO
# 095 EO
# 096 A 1
# 096 A2
# 096 A3
# 096 DO
# 096 E O
# 096 F O
# 096 G 1
# 096 G2
# 096 H 1
# 096 H2
# 096 H 3
#
# 096 K 1
# 096 K 2
# 096 K 3
# 096 KA
# 096 K5
#
# 097 AO
# 097 BO
# 097 C1
# 097 C2
# 097 C3
# 097 C4
# 097 C5
# 097 C6
# 098 A 1
# 098 A2
# 122 A1
# 122 A2
# 122 A3
#
# 123 AO
# 123 BO
# 123 CO
# 123 DO
# 123 EO
#
# 124 BO
# 124 C 1
# 124 C2
# 124 DO
# 124 EO
# 124 FO
# 124 GO
# 125 A1
# 125 A2
# 125 A3
#
# 125 B1
# 125 B2
# 125 EO
# 126 A1
# 126 A2
# 126 BO
#
# 126 DO
# 126 E 1
# 126 E2
# 126 E 3
# 126 E4
#
# 127 AO
#
# 127 BO
#
#
# 128 A1
# 128 A2
# 128 A3
# 128 A4
# 128 A5
# 128 B1
# 128 B2
# 128 B3
# 125 D1
# 128 D2
# 129 A1
# 129 A2
# 129 A3
# 129 BO
# 129 CO
# 129 DO
# 129 E 1
# 129 E2
# 129 E3
# 129 E4
# 129 E5
#
# 129 F1
# 129 F2
# 129 GO
# 129 HM 1
# 129 MH2
# 129 MH 3
# 130 A1
# 130 A2
#
# 130 C 1
# 130 C2
# 130 C 3
# 130 C4
# 130 C5
# 130 D1
# 130 D2
# 130 D3
# 130 D4
# 130 D5
# 130 D6
# 130 EO
# 130 FO
# 131 AO
# 131 B1
# 131 B2
# 131 CO
# 131 D1
# 131 D2
# 132 A1
# 132 A2
# 132 A3
# 133 BO
# 133 C 1
# 133 C2
# 133 C 3
# 133 C4
# 133 C5
#
# 133 DO
# 133 E 1
# 133 E2
# 133 E 3
# 133 E4
# 133 GO
# 134 A 1
# 134 A2
# 134 A3
# 134 A4
# 134 BO
# 134 CO
# 134 DO
#
# 134 E 1
# 134 E2
# 134 E 3
# 134 E4
# 135 A1
# 135 A2
# 135 A3
# 135 A4
# 135 BO
#
# 135 CO
# 135 D1
# 135 D2
# 135 D3
# 135 D4
# 135 FO
# 135 GO
# 136 A 1
# 136 A2
# 136 A3
# 137 A1
# 137 A2
# 137 A3
# 137 A4
# 137 A5
# 137 CO
#
# 138 AO
# 138 BO
# 138 CO
# 138 DO
# 138 EO
# 138 FO
# 139 A1
# 139 A2
# 139 CO
# 141 BO
# 141 C 1
# 141 C2
# 141 C3
# 141 C4
#
# 142 A1
# 142 A2
# 142 A3
# 142 A4
# 142 A5
# 142 A6
# 143 AO
# 143 BO
# 143 D1
# 143 D2
# 143 D3
# 143 D4
#
# 143 E1
# 143 E2
# 143 E3
# 143 E4

# %%
data.bz
# Out:
# [['094B1', '5 FI', '1 LA', '3 BU', '1 TA', ''],
#  ['094B2', '', '', '', '', ''],
#  ['094D1', '6 FI', '3 TA', '1 BU', '', ''],
#  ['094D2', '5 FI', '2 BU', '2 TA', 'T AH', ''],
#  ['094D3', '6 Fl', '2 ZTA', '2 BU', '', ''],
#  ['094D4', '6 Fl', '2 BU', '1 TA', '1 LA', ''],
#  ['094D5', '', '', '', '', ''],
#  ['094D6', '6 Fl', '2 ZTA', '2 BU', '', ''],
#  ['094G0', '', '', '', '', ''],
#  ['094I0', '7 /FI2TA', '1 BU', '', '', ''],
#  ['094K1', '5 FI', '2 TA', '2 BU', 'T AH', ''],
#  ['094K2', '5 FI', 'T TA', '2 BU', '2 AH', ''],
#  ['094K3', '5 FI', '1 TA', '2 BU', '2 AH', ''],
#  ['094K4', '5 FI', '1 LA', '2 AH', '1 BU', '1 TA'],
#  ['094K5', 'A FIZAH', '2 BU', '1 TA', '1 LA', ''],
#  ['094K6', '6 Fl', '1 TA', '1 BU', '2 AH', ''],
#  ['094L1', '3 BU', '2 TA', '2 LA', '5 Fl', ''],
#  ['094L2', '3 BU', '1 ITA', '2 LA', 'A FI', ''],
#  ['094M1', '', '', '', '', ''],
#  ['094M2', '7 /FI2TA', '1 BU', '', '', ''],
#  ['094M3', '5 FI', '2 BU', '2 TA', 'T AH', ''],
#  ['094MA', '', '', '', '', ''],
#  ['094M5', '5 Fl', '2 BU', 'T AH', '2 LA', ''],
#  ['095A1', 'o SFI', '2 BU', '2 TA', 'T AH', ''],
#  ['095A2', 'A FI', '3 BU', '1 TAH', '1 TA', '1 LA'],
#  ['095A3', '5 FI', '2 BU', '2 AH', '1 TA', ''],
#  ['095A4', '5 FI', '2 BU', 'T AH', '1 TA', '1 LA'],
#  ['095B0', '5 SFI', '3 BU', '1 AH', '1 TA', ''],
#  ['095C1', '5 FI2BU', 'T AH', '1 TA', '1 LA', ''],
#  ['095C2', '5 FI', '2 BU', 'T TA', '2 LA', ''],
#  ['095D0', 'A FI', '3 BU', '2 AH', '1 TA', ''],
#  ['095E0', '', '', '', '', ''],
#  ['096A1', '5 FI', '2 BU', '2 TA', 'T AH', ''],
#  ['096A2', '6 Fl', '2 BU', '1 TTA', '1 SL', ''],
#  ['096A3', '', '', '', '', ''],
#  ['096D0', '5 FI', '3 BU', 'T AH', '1 TA', ''],
#  ['096E0', '7 FI', '2 BU', '1 TA', '', ''],
#  ['096F0', 'A FI', '2 BU', '3 SL', '1 TA', ''],
#  ['096G1', '5 FI', '3 BU', '1 TA', 'T AH', ''],
#  ['096G2', 'A FI', 'T TA', '2 AH', '2 BU', '1 SL'],
#  ['096H1', 'A FI', '3 BU', 'T AH', 'T ITA', '1 LA'],
#  ['096H2', '6 Fl', '2 BU', '1 TA', 'T AH', ''],
#  ['096H3', 'A FI', '3 BU', 'T AH', '1 SL', '1 TA'],
#  ['096K1', '5 FI', '2 BU', 'T AH', 'Z TA', ''],
#  ['096K2', '5 FI', 'T BU', 'Z AH', 'Z TA', ''],
#  ['096K3', '5 FI', '2 BU', 'T AH', 'Z TA', ''],
#  ['096KA', 'A FI', '3 BU', '1 TA', 'T AH', '1 SL'],
#  ['096K5', '5 FI', '2 BU', '2 SL', '1 LA', ''],
#  ['097A0', '5 FI2', '8 U', 'T AH', '2 TA', ''],
#  ['097B0', '5 FI', '2 BU', 'T AH', 'Z TA', ''],
#  ['097C1', 'A FI', '2 BU', '1 SL', '1 LA', 'Z TA'],
#  ['097C2', '6 Fl', '2 BU', '1 SL', '1 TA', ''],
#  ['097C3', '5 FI', '2 BU', '1 SL2TA', '', ''],
#  ['097C4', '5 FI', '2 BU', 'T AH', 'Z TA', ''],
#  ['097C5', 'A FI', '3 BU', '2 SL', '1 TA', ''],
#  ['097C6', '5 SFI', '2 BU', 'T AH', 'Z TA', ''],
#  ['098A1', 'A FI', '2 LA', '3 BU', '1 TA', ''],
#  ['098A2', 'A FI', '3 BU', '2 LA', 'T TA', ''],
#  ['122A1', '6 Fl', '3 TA', '1 BU', '', ''],
#  ['122A2', '', '', '', '', ''],
#  ['122A3', '', '', '', '', ''],
#  ['123A0', '2 FI', '5 BU', '2 TA', '1 SL', ''],
#  ['123B0', 'A FI', '3 BU', '1 AH', '1 LA', '1 TTA'],
#  ['123C0', '8 U', 'Z TA', '2 AH', '1 SL', ''],
#  ['123D0', 'A FI', '3 TA', '3 BU', '', ''],
#  ['123E0', '6 Fl', '2 BU', '1 TA', 'T AH', ''],
#  ['124B0', '3 FI', 'A BU', 'T AH', '1 TA', '1 SL'],
#  ['124C1', '5 FI', '3 BU', '2 TA', '', ''],
#  ['124C2', '8 BU', '1 FI', '1 SL', '', ''],
#  ['124D0', '5 FI', 'Z TA', '3 BU', '', ''],
#  ['124E0', '5 FI', '3 BU', '2 TA', '', ''],
#  ['124F0', '3 FI', '4 BU', '2 TA', '1 SL', ''],
#  ['124G0', '3 FI', 'A BU', '1 SL', '2 TA', ''],
#  ['125A1', 'A FI', '3 TA', '2 BU', '1 SL', ''],
#  ['125A2', '/ FIZTA', 'T AH', '', '', ''],
#  ['125A3', '6 Fl', '2 Z2TA', 'T AH', '1 BU', ''],
#  ['125B1', 'A FI', '3 BU', '2 TA', '1 SL', ''],
#  ['125B2', 'A FI', 'A BU', '1 TA', '1 SL', ''],
#  ['125E0', 'A FI', '3 BU', '2 TA', '1 SL', ''],
#  ['126A1', '', '', '', '', ''],
#  ['126A2', '', '', '', '', ''],
#  ['126B0', '6 Fl', '1 TA', 'T BU', 'T AH', ''],
#  ['126D0', '', '', '', '', ''],
#  ['126E1', '6 FI', '2 TA', '2 BU', '', ''],
#  ['126E2', '6 Fl', '2 BU', '1 TA', 'T AH', ''],
#  ['126E3', '5 FI', '3 BU', 'T TA', 'T AH', ''],
#  ['126E4', '5 FI', '3 BU', 'T TA', '1 SL', ''],
#  ['127A0', '5 FI', '3 BU', '1 TA', '1 SL', ''],
#  ['127B0', '5 FI', '3 BU', 'T AH', '1 TA', ''],
#  ['128A1', '6 Fl', '2 BU', '2 TA', '', ''],
#  ['128A2', '7 FI', '1 BU', 'T AH', '1 TA', ''],
#  ['128A3', '', '', '', '', ''],
#  ['128A4', '6 FI', '1 LA', '1 TA', '1 BU', 'T AH'],
#  ['128A5', '6 Fl', '2 BU', '2 TA', '', ''],
#  ['128B1', '5 FI', '3 BU', 'T TA', 'T AH', ''],
#  ['128B2', '5 FI', '3 BU', '1 TA', '1 SL', ''],
#  ['128B3', '', '', '', '', ''],
#  ['125D1', '6 Fl', '2 BU', '1 TTA', 'T AH', ''],
#  ['128D2', 'A FI', '3 BU', '1 TA', '1 LA', 'T AH'],
#  ['129A1', '5 FI', 'Z AH', '2 SL', 'T ITA', ''],
#  ['129A2', '5 FI', '3 AH', 'T BU', '1 TA', ''],
#  ['129A3', '5 FI', '3 AH', '1 BU', '1 TTA', ''],
#  ['129B0', '', '', '', '', ''],
#  ['129C0', '5 FI', 'T TA3AH', '1 SL', '', ''],
#  ['129D0', '', '', '', '', ''],
#  ['129E1', '7 /FI', '2 TA', '1 BU', '', ''],
#  ['129E2', '7 FI2BU', '1 TA', '', '', ''],
#  ['129E3', '7 FI', 'T AH', '1 BU', '1 TA', ''],
#  ['129E4', '7 /FI2TA', '1 BU', '', '', ''],
#  ['129E5', '7 FI', 'T AH', '1 SL', '1 TA', ''],
#  ['129F1', '/ FI2TA', '1 BU', '', '', ''],
#  ['129F2', '/ FIZTA', '1 BU', '', '', ''],
#  ['129G0', '7 /FI', 'T AH', '1 TA', '1 SL', ''],
#  ['129HM1', '7 /FI2TA', '1 BU', '', '', ''],
#  ['129MH2', '', '', '', '', ''],
#  ['129MH3', '6 Fl', '2 ZAH', '1 SL', '1 TA', ''],
#  ['130A1', '', '', '', '', ''],
#  ['130A2', '7 FITAH', 'T TA', '1 SL', '', ''],
#  ['130C1', '7 FI', '2 TA', '1 BU', '', ''],
#  ['130C2', '5 SFI', '3 BU', '2 TA', '', ''],
#  ['130C3', '', '', '', '', ''],
#  ['130C4', '5 FI', 'Z TA', '3 BU', '', ''],
#  ['130C5', '7 FI', '2 BU', '1 TA', '', ''],
#  ['130D1', '7 /FITAH', '1 TTA', '1 SL', '', ''],
#  ['130D2', '/ FIZAH', '1 TTA', '', '', ''],
#  ['130D3', '', '', '', '', ''],
#  ['130D4', '7 /FIZAH', '1 TA', '', '', ''],
#  ['130D5', '', '', '', '', ''],
#  ['130D6', '6 Fl', '1 BU', '1 ISL', '2 TA', ''],
#  ['130E0', '7 FI', 'T LA', 'T AH', '1 SL', ''],
#  ['130F0', '7 FI2TA', 'T AH', '', '', ''],
#  ['131A0', 'A FI', '2 TA', '2 BU', '2 AH', ''],
#  ['131B1', 'A FI', '3 TA', '3 SL', '', ''],
#  ['131B2', '3 Fl', 'T TA', '5 AH', '1 SL', ''],
#  ['131C0', 'A FI', '2 TA', '2 BU', '2 AH', ''],
#  ['131D1', 'A FI', '2 TA', '2 BU', '2 AH', ''],
#  ['131D2', '5 FI', '3 TA', 'T AH', '1 BU', ''],
#  ['132A1', '3 FI', '2 TA', '2 BU', '2 AH', '1 SL'],
#  ['132A2', 'A FI', 'Z TA', '2 AH', '2 SL', ''],
#  ['132A3', '2 FI', '4 AAH', 'Z TA', '2 SL', ''],
#  ['133B0', '6 FI2TAZAH', '', '', '', ''],
#  ['133C1', '7 FI', '2 TA', '1 BU', '', ''],
#  ['133C2', '8 Fl', '1 BU', '1 TA', '', ''],
#  ['133C3', '7 FITAH', '1 BU', '1 TA', '', ''],
#  ['133C4', '5 FI', '3 AH', '1 BU', '1 TA', ''],
#  ['133C5', '6 Fl', '2 ZAH', '1 BU', '1 TA', ''],
#  ['133D0', '5 FI', '2 AH', '2 BU', '1 TA', ''],
#  ['133E1', '5 FI', '2 BU', '2 SL', '1 TA', ''],
#  ['133E2', 'A FI', '2 TA', '2 AH', '2 SL', ''],
#  ['133E3', 'F I', '2 BU', '2 AH', '1 TA', ''],
#  ['133E4', '5 FI', '2 BU', '2 SL', '1 TA', ''],
#  ['133G0', '5 FI', '2 SL', '3 TA', '', ''],
#  ['134A1', '', '', '', '', ''],
#  ['134A2', '6 FI', '2 AH', '1 BU', '1 TA', ''],
#  ['134A3', '', '', '', '', ''],
#  ['134A4', 'A FIAAH', '1 ITA', '1 SL', '', ''],
#  ['134B0', '5 FI', '2 BU', 'T AH', '2 TA', ''],
#  ['134C0', '', '', '', '', ''],
#  ['134D0', '5 FI', '3 BU', '2 TA', '', ''],
#  ['134E1', '6 Fl', '3 TA', '1 BU', '', ''],
#  ['134E2', '6 Fl', '1 BU', '1 SL2TA', '', ''],
#  ['134E3', '', '', '', '', ''],
#  ['134E4', '6 Fl', '1 BU', '2 LA', 'T AH', ''],
#  ['135A1', '', '', '', '', ''],
#  ['135A2', '5 SFI3AH', '2 TA', '', '', ''],
#  ['135A3', '6 Fl', '2 AH', '1 BU', '1 TA', ''],
#  ['135A4', '6 FI', 'T AH', '1 BU', '2 TA', ''],
#  ['135B0', '5 FI', '2 BU', 'T AH', '2 TA', ''],
#  ['135C0', '7 /FI', '2 BU', '1 TA', '', ''],
#  ['135D1', '6 Fl', '1 BU', '2 AH', '1 ITA', ''],
#  ['135D2', '5 FI', '3 AH', '2 TA', '', ''],
#  ['135D3', '6 Fl', '3 AH', '1 BU', 'T TA', ''],
#  ['135D4', '3 FI', '3 AH', '1 SL3TA', '', ''],
#  ['135F0', '7 /FI', '2 TA', '1 AH', '', ''],
#  ['135G0', '5 SFI', 'Z AH', '1 BU', '2 TA', ''],
#  ['136A1', '7 FI', '2 BU', 'T AH', '', ''],
#  ['136A2', '7 FI', '2 LA', '1 BU', '', ''],
#  ['136A3', '5 FI', '2 BU', '1 ITA', '2 AH', ''],
#  ['137A1', '5 FI2BU', '2 LA', '1 TA', '', ''],
#  ['137A2', '5 SFI', '2 BU', '2 LA', '1 TA', ''],
#  ['137A3', '5 FI2BU', '2 LA', '1 TTA', '', ''],
#  ['137A4', '5 FI', '2 BU', '2 LA', 'T AH', ''],
#  ['137A5', '5 FI', '2 BU', '1 SL', 'T TA', 'T ILA'],
#  ['137C0', '7 FI', '2 BU', '1 TA', '', ''],
#  ['138A0', '6 FI', '2 LA', '2 BU', '', ''],
#  ['138B0', '6 Fl', '2 BU', '1 ITA', '1 LA', ''],
#  ['138C0', '6 Fl', '2 BU', 'T AH', '1 LA', ''],
#  ['138D0', '5 FI', '2 BU', '2 LA', '1 TTA', ''],
#  ['138E0', '5 FI', '1 LA', '2 BU', 'T TA', 'T AH'],
#  ['138F0', '6 Fl', '1 BU', '2 TA', 'T AH', ''],
#  ['139A1', 'A FI', '2 BU', '2 TA', '2 LA', ''],
#  ['139A2', '7 /FI', '3 LA', '', '', ''],
#  ['139C0', 'A FI', '2 LA', '3 BU', 'T AH', ''],
#  ['141B0', '6 Fl', '1 TA', '2 BU', 'T AH', ''],
#  ['141C1', '6 Fl', '3 TA', 'T AH', '', ''],
#  ['141C2', '/ FITTA', '2 AH', '', '', ''],
#  ['141C3', '6 Fl', '2 BU', 'T TA', 'T AH', ''],
#  ['141C4', '7 /FI2BU', '1 TA', '', '', ''],
#  ['142A1', '6 Fl', '2 TA', '1 BU', 'T AH', ''],
#  ['142A2', '', '', '', '', ''],
#  ['142A3', '7 FI', '1 TA', 'T AH', '1 BU', ''],
#  ['142A4', '7 /FI2TA', '1 SL', '', '', ''],
#  ['142A5', '5 FI', '3 AH', '1 BU', '1 TA', ''],
#  ['142A6', '/ FITTA', 'T AH', '1 BU', '', ''],
#  ['143A0', '5 FI', 'A H', '2 BU', '1 TA', ''],
#  ['143B0', 'A FI', '2 AH', '1 GE', '3 TA', ''],
#  ['143D1', '7 /FIIBU', 'T AH', '1 TA', '', ''],
#  ['143D2', '6 Fl', '3 TA', 'T AH', '', ''],
#  ['143D3', '7 FI2TA', 'T AH', '', '', ''],
#  ['143D4', '6 Fl', 'Z TA', 'T AH', 'T BU', ''],
#  ['143E1', '', '', '', '', ''],
#  ['143E2', '', '', '', '', ''],
#  ['143E3', '', '', '', '', ''],
#  ['143E4', '6 Fl', '3 TA', 'T AH', '', '']]

# %%
data.text
# Out:
# [['094B1',
#   'ST   unten STOE 23',
#   'BE   oben vl BU, an Besitzgrenze Wiesen-BL, unten älter u besser, vl Lagerholz, Fl teils geringe Kronen unten stabiler, einz. TA',
#   'MA   ZV, 1 GH, nächstes Dez. LI KH Verbot!',
#   '',
#   ''],
#  ['094B2', '', '', '', '', ''],
#  ['094D1',
#   'ST   verkrautet und teils vergrast, vl Bäche',
#   '',
#   'BE   wenig VJ, TA verbissen; im SO an STR jger, unten vl TA, einz. BU; anerkannter Saatgut-BE, im W s lückig, geschlägerte Käferbäume, im O dichter',
#   'und vi Wipfelbrüche',
#   ''],
#  ['094D2',
#   'ST   Bacheinhang',
#   'BE   unglalt, ein LH in jüngerer Schicht, etwas UL, vl TA',
#   'MA   DF TA/AH fördern',
#   '',
#   ''],
#  ['094D3',
#   'ST   O-TL stk beweidet, 3 Teile',
#   'BE   einige BU/ES, im Mittel-TL vi AH, im W von O-TL 5 J jger, Schneeschäden 2019, Gassen vorhanden, im W Teil Schneebruch aufgearbeitet',
#   'MA   DF/DE Schadholz aufarbeiten undurchforstet Teile pflegen',
#   '',
#   ''],
#  ['094D4',
#   'BE   2 TLE, unglalt, 20-35 jg, Gruppenstruktur, vl BU, LA ober Straße, teils Schneedruckschäden',
#   'MA   Scgadholz 2020, belassen, ende Dez prüfen, ob DF',
#   '',
#   '',
#   ''],
#  ['094D5', '', '', '', '', ''],
#  ['094D6',
#   'BE   ungleichalt (10-20) überwiegend NH-VJG, ein LH TA stark verbissen, eine',
#   'FI-Vorwuchsgruppe, Schneeschäden',
#   'MA   guter Abstand der FI belassen, nächstes Dez DE',
#   '',
#   ''],
#  ['094G0', '', '', '', '', ''],
#  ['094I0',
#   'ST   leicht geneigter Hang',
#   '',
#   'BE   zu Alm im O besser vorwüchsig, vl TA/AH Keimlinge am Boden, TA Reichtum, Stabil, neue',
#   'Straße: Kalleckweg',
#   ''],
#  ['094K1',
#   'ST   2 TLE, oben STOE 22, Übergang zu VTYP B',
#   '',
#   'BE   vI TA/AH, im N von S-TL s stk TA, bei Stein 2/40 schlechter, ES VJ verbissen, vi TA/AH Keimlinge, im unteren Teil mittig Lücke durch',
#   'Schadereignis',
#   ''],
#  ['094K2',
#   'ST   Hang WS/B',
#   'BE   zir ES, oben fast reine FI, zir Wipfelbrüche, unter Straße vi LH',
#   'MA   DF 2000 im SW, DF letzter Eingriff vor EN, AH Kronenpflege, 2020 Schneedruck Aufarbeitung, ZV',
#   '',
#   ''],
#  ['094K3',
#   'BE   2 TLE, im W 5 J jger, BU-Horst bei KK 141, Schneebruch 2019, unter Straße gut durchforstet, ober',
#   'Straße noch nicht',
#   'MA   DF/ZV',
#   '',
#   ''],
#  ['094K4',
#   'ST   Hainsimse, Heidelbeere, B/BH',
#   'BE   3 TLE, vl AH, einz LA/EE, im W von W-TL 5 J jger, im S bei Straße LH-reicher, Schmalkronig, Fl schlechtwüchsig',
#   'MA   DE9O',
#   '',
#   ''],
#  ['094K5',
#   'ST   etwas vergrast',
#   'BE   großer Verbissdruck auf LH, vI AH, LH Gruppe in Mitte, Fl teils Solitär und tief bekront',
#   'MA   späte DP bei Fl',
#   '',
#   ''],
#  ['094K6',
#   'ST   oben STOE 23 Übergang WS/BH',
#   'BE   Kalamität 2004, unglalt, 5-20 jg, vI LH, etwas EE/UL, im SO, einz FI-Vorwuchshorst',
#   'MA   DP 2020, ende Dez. AH Asten',
#   '',
#   ''],
#  ['094L1',
#   'ST   felsig, etwas vergrast; LRV',
#   '',
#   'BE   durch WW/Käfer geschädigt, Fl nahezu ausgefallen, Alttannen und Buchen von jüngeren BU unterwandert, am Rand etwas BU VJ',
#   'und vl Totholz',
#   ''],
#  ['094L2',
#   'ST   felsig, trocken, etwas Schlagvegetation',
#   'BE   aus WW und Käfernutzung; Pflanzung 2011, SL= ME/EE/ES/WD/BI; ST= Hasel/Holunder',
#   'MA   Mitte Dez. prüfen, ob DP notwendig (LA)',
#   '',
#   ''],
#  ['094M1',
#   'ST   Zufahrt zu Almgebäude, Bach',
#   'BE   sehr innomogen, zT VJ aufkommend, verbissen, etwas jüngere TA/AH/FI (25-45j)',
#   'MA   PL, Bejagen!',
#   '',
#   ''],
#  ['094M2',
#   'BE   im NW älter, einz. AH/BU, etwas lückig, an Straße Jungwuchskegel mit Schneedruckschäden',
#   'MA   Schadholz 2020, belassen',
#   '',
#   '',
#   ''],
#  ['094M3',
#   'ST   oben viel Geröll, Wanderweg',
#   'BE   2 TLE, längs Steig schlechter, oberhalb vl Schneebruch 2019, einige AH/BU',
#   'MA   DF gemeinsam mit ZV',
#   '',
#   ''],
#  ['094MA',
#   'ST   Rutschung ober STR im O',
#   'BE   2 TLE, vl BU/AH/GE, LH dominiert',
#   'NA DE ab Mitte Dez. FI freistellen, LH Kronenpflege',
#   '',
#   ''],
#  ['094M5',
#   'ST   teils etwas vergrast, und oben felsiger 23/22',
#   'BE   überwiegend FI, einige LA, LH stark verbissen, SL= ES/EE/WD, einz. TA ebenfalls stark verbissen, einz. Schneeschub',
#   'MA   ab Mitte Dez. Kontrolle ob bereits DP',
#   '',
#   ''],
#  ['095A1',
#   'ST   örtl felsig, alter Traktorweg, Übergang WS/B, 23/22',
#   'BE   zir BU AH, nach oben schlechter werdend, vi Totholz, an Traktorweg viel ältere BU VJ unter Schirm, im NO BU stark verbissen TA nur als Keimlinge',
#   'MA   Altschicht entnehmen (RM)',
#   '',
#   ''],
#  ['095A2',
#   'ST   Rücken, 22, Südseite, LRV',
#   'BE   BE-Rest, sehr viel Totholz, Fl absterbend und schlechtwüchsig, Im O mehr BU/TA, im W viel FI',
#   'MA   ZV, mit PO nutzen',
#   '',
#   ''],
#  ['095A3',
#   'ST   Hang, B',
#   'BE   vl AH/ES, s eng aufgewachsen, im N kaum LH, UE am Oberhang und undurchforstet',
#   'MA   DE 2011/2012, DF ende Dez. unter Straße, ober Straße DE!',
#   '',
#   ''],
#  ['095A4',
#   'ST   teils etwas vergrast, Südhang',
#   'BE   unglalt, 5-20 jg, LH teils jünger, tief bekront und stabil, LA ober Straßen (Knicklaus)',
#   'MA   DP 2020 durchgeführt, belassen LA beobachten',
#   '',
#   ''],
#  ['095B0',
#   'ST   oben Trümmergestein',
#   'BE   im SO fast reines LH, nach oben NH zunehmend, dicht Kronendach zumeist geschlossen, einz. ES, vl Totholz, vl AH Keimlinge',
#   'MA   2007 u 2008 zIr WW, VJ Einleiten von NO beginnen (LI) + GH!',
#   '',
#   ''],
#  ['095C1',
#   'ST   im SO felsig mit STOE 21, unten alter Zugweg eher Steig',
#   'BE   ungleichalt, Altbestand auflösend, Jungbesrand dominierend, hauptsächlich LH',
#   'MA   2. Schicht DF, teile des Altbestand entnehmen',
#   '',
#   ''],
#  ['095C2',
#   'BE   kaum Vegetation am Boden',
#   'BE   dicht, ein BU UL, vl Schneebruch 2019',
#   'MA   DE/ZV',
#   '',
#   ''],
#  ['095D0',
#   'ST   WS/HS, Wasserfassung',
#   'BE   im NO ein FI-Horst, einz TA, an Graben vl Hasel u sonst LH, etwas VJ unter Schirm (BU/FI/AH/ES), viel Totholz, Specht',
#   'MA   belassen',
#   '',
#   ''],
#  ['095E0', '', '', '', '', ''],
#  ['096A1',
#   'ST   oben steinig, unten flacher, in d Mitte STOE 32',
#   'BE   im NW fast reine FI, im NO freigestellter FI-JUWU-Horst (= A2 ), Straße wurde verlängert',
#   'MA   im O LI, über 97 AO mit Schlepper fahren, unter Straße mit 97 BO hochseilen!',
#   '',
#   ''],
#  ['096A2',
#   'BE   23, B, kaum Vegetation am Boden',
#   'BE   ehrmaliger Femelhorst, dicht, ein ES AH, viel Schneebruch 2019',
#   'MA   ZV/DE',
#   '',
#   ''],
#  ['096A3', '', '', '', '', ''],
#  ['096D0',
#   'ST   unten STOE 32',
#   'BE   zIr TA und ES oben undurchforstet und sehr Stammzahlreich bzw dicht, unten bereits DF sehr unglalt',
#   'MA   oberen Teil DF, ES entnehmen, AH/TA fördern, unten belassen',
#   '',
#   ''],
#  ['096E0',
#   'ST   32 SS/SF/B',
#   'BE   zIr TA, AH/BU mehr im Zwi-BE, 1992 stk durchforstet',
#   'MA   ZE, LI erst wenn H4 gesichert',
#   '',
#   ''],
#  ['096F0',
#   'ST   verkrautet, viel Brombeere, Gamsverbiss weiter oben',
#   'BE   vl ES, etwas BU, FI droht überwachsen zu werden, einz. LI/ME, FI 2017 gepflanzt',
#   'MA   JP,KE (Fl streichen)',
#   '',
#   ''],
#  ['096G1',
#   'ST23SS',
#   'BE   vl AH, WW u DF 2009/2018, Schneebruch 2019, licht',
#   'MA   DE 2018, Schneebruch 2019; ZV, belassen',
#   '',
#   ''],
#  ['096G2',
#   'ST   B/SW verstaudet, Haselhuhn Gebiet',
#   '',
#   'BE   unglalt, zIr Hasel, aus RM 1991, 1992 u 1996, jeweils 500 Fl ergänzt, laufend Schadholz; viel UL teils absterbend (Ulmenwelke), einz. KB/TA, SL=UL EE',
#   'KB',
#   ''],
#  ['096H1',
#   'ST   im © felsig u STOE 22',
#   'BE   gegen O schlechter werdend, im SO durchforstet, laufend Käfer 2008 u 2009, Keimlingsverjüngung, einz alte LA, sehr lückig!',
#   'MA   auf VJ warten, SchwerpunktBejagung, ZE',
#   '',
#   ''],
#  ['096H2',
#   'ST   B/WS 23/32',
#   'BE   unglalt, schöne BA Mischung, DF 2002, etwas Schadholz, ES absterbend',
#   'MA   belassen, bei ZE UL fördern',
#   '',
#   ''],
#  ['096H3',
#   'ST   Hasel, Brombeere und Farn',
#   'BE   FI Schneedruck, LH stark verbissen, teils aus dem Äser, einz. UL',
#   'MA   Bejagen, DP: Mitte Dez. Fl freistellen, geschädigte entfernen',
#   '',
#   ''],
#  ['096K1',
#   'ST   örtl felsig',
#   'BE   oben mehr BU, ungleichalt',
#   'MA   Altholz belassen!',
#   '',
#   ''],
#  ['096K2',
#   'ST   Gräben und Rücken, Schlagvegetation aufkommend, unten besser 23 oben Übergang zu 22',
#   'BE   DF 2001, 2003, vl Schneebruch, WW und Käfer, sehr licht in Mitte Blöße',
#   'MA   nach 5J. mit FI EG wenn nötig',
#   '',
#   ''],
#  ['096K3',
#   'BE   vIESULAH, unglalt, im unteren TL AH Gruppen, bei Stichweg DF erfolgt und licht',
#   'MA   2017/2019 DF, teils etwas Schadholz, ZV',
#   '',
#   '',
#   ''],
#  ['096KA',
#   'ST   einz. Felsrippen',
#   'BE   2 TLE, im S ES-reicher, Fl schmalkronig, stark Schneedruck geschädigt (80%), einz. ME, unter Straße Fl Horst DE90',
#   'MA   DE 2017; ZV/DE, FV/AH/UL freistellen, Vorwuchs-BU-Horste belassen',
#   '',
#   ''],
#  ['096K5',
#   'BE   Fl Schneedruck geschädigt, ES biologisch 5-10 J älter, extremer Gamsverbiss auch an Fl, auch Samenverb',
#   'MA   Schwerpunktbejagung! Schussschneise! sonst belassen',
#   '',
#   '',
#   ''],
#  ['097A0',
#   'ST   oben felsig mit STOE 22',
#   'BE   ziIr TA, vl Schneebruch 2019, oben schlechter, LH s dicht mit geringen BHD',
#   'MA   LH DF/LI, gemeinsam mit BO, oben Schlepper mit AT 96 nutzen',
#   '',
#   ''],
#  ['097B0',
#   'STSS',
#   'BE   unten 40 J älter, einz WW, unverjüngt',
#   'MA   LI gemeinsam mit AO',
#   '',
#   ''],
#  ['097C1',
#   'ST   längs Grenze felsig u 35 Grad nach SW geneigt, Wanderweg',
#   'BE   zir BU, einz. UL/EB, sehr schön strukturiert',
#   'MA   DF 2012, im Ebenen an Weg JF',
#   '',
#   ''],
#  ['097C2',
#   'ST   oben STOE 22',
#   'BE   oben schlechter u mehr BU, zir alte Schälschäden, teils Dürrlinge, sehr unterschiedliche BHD, LH teils jünger',
#   'MA   mit AO LI!',
#   '',
#   ''],
#  ['097C3',
#   'ST   teils etwas Blockig',
#   '',
#   'BE   2 TLE, im Mittel-TL kaum NH, im S an Grenze 0.2 ha 10 J jger u reines NH, Schneebruch 2019 50%, einige ES, UL, unten bereits DF oben',
#   'ungepflegt',
#   ''],
#  ['097C4',
#   'ST   HS 32, alter Hohlweg',
#   'BE   sehr unglalt, etwas Hasel unter Schirm, Fl etwas jünger (15j) LH vorwüchsig',
#   'MA   DF LH zurückdrängen, FI freistellen (Servitut)',
#   '',
#   ''],
#  ['097C5',
#   'ST   oberhalb Zugweg felsig u STOE 21 im Ebenen 23, Felsband',
#   'BE   zir BU-Vorwüchse aus ehem Zwi-BE, etwas AH/ES/UL, FI stark Schneebruch 2019 geschädigt, unaufgearbeitet',
#   'MA   DE 90 Schneeschäden',
#   '',
#   ''],
#  ['097C6',
#   'ST   HS 23',
#   '',
#   'BE   vI TA AH UL, s unglalt, 20-30 jg, BU im Neben-BE   absinkend, NH vermehrt im N, stark Schneebruch geschädigt, DE hat',
#   'Natur durchgeführt',
#   ''],
#  ['098A1',
#   'ST   oberhalb Zugweg Tagfelsgruppen, zugewachsener Wanderweg, unten STOE 23/32 oben 22',
#   'BE   nach oben schlechter werdend u Bestockung abnehmend, vl AH-ES-JUWU, im W kaum FI-JUWU',
#   'MA   PL Überalterte TA/FI/BU entnehmen',
#   '',
#   ''],
#  ['098A2',
#   'ST   Waldrebe, flacher Graben',
#   'BE   unglalt, 15-25 jg, im N älter, einz MB, EE; sehr dicht',
#   'MA   DE alternativ 90, BU in Gruppen dicht lassen',
#   '',
#   ''],
#  ['122A1',
#   'ST   Stark toniger Rücken, beweidet',
#   'BE   ältere Randbäume, ungleichalt viele junge TA (teils mit Tannenkrebs), ungepflegt',
#   'MA   DF TA fördern (Servitut)',
#   '',
#   ''],
#  ['122A2',
#   'ST   dicht kaum Vegetation am Boden, beweidet',
#   'BE   ungleich, einz BU/BI/EE, viel Schneebruch 2019 unaufgearbeitet, teils dicht, TA unterschiedlichsten Alters, W Rand blößig',
#   'MA   Schneebruch aufarbeiten, DE, gegen Weidevieh zäunen',
#   '',
#   ''],
#  ['122A3', '', '', '', '', ''],
#  ['123A0',
#   'ST   steil im S Blockade im N Feinerde, kaum Vegetation am Boden, Grabeneinhang teils vergrast, Gams',
#   'BE   BU-Jugend krummwüchsig, durch Lawinen eingerissen, einz FI-TA-VJG-Horste, viel Totholz durch WW',
#   'MA   Standortschutzwald! hohe Bestockung erhalten',
#   '',
#   ''],
#  ['123B0',
#   'ST   unten STOE 23, etwas Blockmaterial, Gamseinstand, LRV',
#   '',
#   'BE   Artenreich, überwiegend LH; einz TA, FI vorw im O, ausfallend; in lichteren Teilen viel BU Vj,',
#   'viel Totholz aus WW',
#   ''],
#  ['123C0',
#   'ST   etwas blockig, Übergang K/B/WS, Gams',
#   'BE   an d Grenze im SW durch Lawinen eingerissen und mehr BU, nur einz LI/TA/FI, einige ES, wo lichter, da kommt flächig BU NVj, in Lawinenrinne Legbuche.',
#   'MA   belassen',
#   '',
#   ''],
#  ['123D0',
#   'ST   Lawinen u Gräben, Blockig',
#   'BE   zweischichtig, wenig Fl in Jungschicht, hoher TA Anteil, Fl überaltert, Einzel WW',
#   'MA   VJ einleiten, PL überalterte Fl entnehmen',
#   '',
#   ''],
#  ['123E0',
#   'ST   blockig, feucht, Hangbewegung (Säbelwuchs bei BU), etwas Bärlauch, Specht',
#   'BE   einz LA, Käferschlag, AH/TA VJ meist verbissen, flächig BU Unter Schirm (Verbuchung ), im N dicht mehr FI und unverjüngt',
#   'MA   belassen',
#   '',
#   ''],
#  ['124B0',
#   'ST   23 Hangbewegung, Übergang VTYP K/SS',
#   'BE   vI AH, einz FI KB EE, ungleichmäßig, aus RM 1993, s schlechte Qualität',
#   'MA   DF: BU Brennholz, AH/UL/TA/FI freistellen',
#   '',
#   ''],
#  ['124C1',
#   'ST   WS/B etwas Farn, Hangbewegung',
#   'BE   ein AH/UL; LA ausgefallen, FI/TA-VJG am Unterhang, in Mitte Verebngungen und BU Vj Kegel',
#   'MA   belassen',
#   '',
#   ''],
#  ['124C2',
#   'ST   Lawinenstrich, Geröllhalde',
#   'BE   vi WE, etw FI TA, unglalt, Ränder älter, Legbuche mit Linde!',
#   'MA   Dauerwald belassen',
#   '',
#   ''],
#  ['124D0',
#   'ST   Hangbewegung, Übergang VTYP B/WS, etwas Farn',
#   'BE   FI/TA Altbestand von reiner BU unterwandert, einz UL, Altholz teils WW, viel Totholz',
#   'MA   ND: um NH Vj zu ermöglichen 40j. BU entnehmen, nach Nutzung vor Weidevieh zäunen',
#   '',
#   ''],
#  ['124E0',
#   'ST   etwas blockig, Übergang von VTYP B/SS',
#   'BE   dicht, Überaltert kaum noch Zuwächse, einz junge BU(40j) beigemischt, einz Wipfelbrüche',
#   'MA   LI, BU entnehmen, um Verbuchung zu vermeiden',
#   '',
#   ''],
#  ['124F0',
#   'ST   22 B, etwas Waldmeister und Bärlauch',
#   'BE   oben fast reine BU, sehr unterschiedlich in DM und Alter, einige Dürrlinge und Alter WW',
#   'MA   belassen',
#   '',
#   ''],
#  ['124G0',
#   'ST   steil Rotwildwechsel, VTYP B, Hangbewegung',
#   'BE   einz. WW, etwas jüngere TA, 5-20j BU Schleier unter Schirm, ein AH/UL',
#   'MA   belassen',
#   '',
#   ''],
#  ['125A1',
#   'ST   bis 40 Grad geneigter Grabeneinhang',
#   'BE   2 TLE, an den Rändern vl VJG, Grabeneinhang schlechter mit BU, BU vor allem im S-TL',
#   'MA   Grabeneinhang belassen, flache Bereiche, Straßenrand UE/JF',
#   '',
#   ''],
#  ['125A2',
#   'ST   eben Übergang zu VTYP SS',
#   'BE   unglalt, aus NVJG, TA/AH tlw bedrängt und jünger, stabile Kronen, gutwüchsig',
#   'MA   leichte DE 2012/2014/2019, weiter in dem Stil DF (früh mäßig oft)',
#   '',
#   ''],
#  ['125A3',
#   'ST   mehrere Teile, teils steiler Bacheinhang, teils eben, einz vernässte Blößen',
#   'BE   sehr ungleichalt 10-35 jg, ein TA/AH/BU UE, einz. Kirsche beigemischt, schöner TA Anteil auch in Jungschicht',
#   'MA   ältere Teile DE! TA fördern (Zaunholz für Servitut)',
#   '',
#   ''],
#  ['125B1',
#   'ST   2 Teile, tief eingeschnittene Gräben, STOE 22-32',
#   'BE   mehrschichtig, Baumriesen, Altschicht in Zerfallsphase, v| Totholz, vi junge BU, einz. junge AH/UL',
#   'MA   im SO im unteren Teil BU ND (Brennholz Servitut)',
#   '',
#   ''],
#  ['125B2',
#   'ST   Übergang SS/HU/WS, Schwarzspecht Höhle besetzt',
#   'BE   ungleichmäßig bestockt und ungleichalt, einz BU/TA aus Vorbestand, FI wird von BU überwuchert, Schneedruck an FI, UL teils gefegt, einz. junge BI, WD',
#   'MA   DP FI freischneiden, BU im Dichtstand und in Gruppen belassen',
#   '',
#   ''],
#  ['125E0',
#   'ST   Schutzwaldcharakter, stk Schneeschub',
#   '',
#   'BE   BU unterschiedliche Dimension, teils jünger, teils Protzig, teils gerade gewachsen, TA bedrängt, AH/UL in Zwischenbestand,',
#   'Specht',
#   ''],
#  ['126A1',
#   'ST   Übergang zwischen VTYP SW/SS/HS, etwas vernässt dort Erlen, unterer Teil beweidet',
#   'BE   etwas jüngere BU, einz ES/LA, ungleichmäßig in Alter und Bestockung, im N reines NH, ziIr Schneebruchschäden, GE meist protzig',
#   'MA   NH reine Teile DF Schneebrüche entnehmen, TA/AH/LA fördern',
#   '',
#   ''],
#  ['126A2',
#   'ST   Übergang SS/SW',
#   'BE   ein LA GE, im NO ehem WE, dort undurchforstet und viele Dürrlinge, einz. LA',
#   'MA   unter Straße DF LA fördern',
#   '',
#   ''],
#  ['126B0',
#   'ST   etwas Farn VTYP SW, teils STOE 23',
#   'BE   unglalt, an "LL1" älter, BU vorwiegend im SW, laufend Schneedruck u WW, einiges Totholz, LH teils jünger',
#   'MA   ZE, GH ab Mitte Dez.',
#   '',
#   ''],
#  ['126D0',
#   'ST   SS/WS Brombeeren',
#   'BE   im W u an unterer STR s unglalt u vI LH, einz LA/TA, DF 2000 u WW 2007, alte Seillinien räumdig u FI-NVJG',
#   'MA   Fütterung verlegen? sonst belassen ZV alternativ GH möglich',
#   '',
#   ''],
#  ['126E1',
#   'ST   Rücken und Gräben',
#   'BE   ungleichmäßig bestockt u gemischt, über Forstweg vl BU NVJ an den Rändern, Verbuchungsgefahr, TA stark verbissen, oben viel Totholz (Specht/LRV)',
#   'MAimS Teil LI: VJ Einleiten, W Teil PL: junge TA/FI fördern, ältere BU entnehmen, bejagen',
#   '',
#   ''],
#  ['126E2',
#   'ST   Übergang SS/SW',
#   'BE   lückig bis dicht, oberer TL jger, vl AH ES, WE in STR Nähe, zumeist protzig; ein LA/TA, Fl oft Schneebruch geschädigt, fällt teilweise aus',
#   'MA   DE BU Protzen entnehmen, dichte FI Gruppen durchschneiden',
#   '',
#   ''],
#  ['126E3',
#   'ST   2 kleinere unbestockte Plaiken, Übergang zu HU, Hangbewegung',
#   'BE   aus RM 1994-1997, einz UL, EE, ES, PO = SL vIf protzig, Fl Schneebruch und Einzel WW',
#   'MAZV',
#   '',
#   ''],
#  ['126E4',
#   'ST   Schlagvegetation',
#   'BE   ungleichalt, etwas BU/AH aus Vorbestand, FI/TA teils von LH überwachsen, SL= ME/EE/WD',
#   'MA   Mitte Dez. DP am Straßenrand FI/TA freischneiden',
#   '',
#   ''],
#  ['127A0',
#   'ST   teils Verebngungen STOE WS/SS',
#   '',
#   'BE   ungleichalt, im NO und S höherer FI-Anteil, BU schlecht geformt, einige TA, einz AH/UL; an Rändern, wo mehr Licht, da Flächig BU NVJ, unter',
#   'Schirm viel TA/BU Keimlinge, vl WW',
#   ''],
#  ['127B0',
#   'ST   teils vernässt',
#   '',
#   'BE   ziIr ESUL TA LA, ungleichmäßig u unglalt, Altholz mit geringen BU BHD, viel Schneebruch 2019, noch unaufgearbeitet und einzeln frischer',
#   'WW',
#   ''],
#  ['128A1',
#   'ST   beweidet',
#   'BE   2 TLE, ein BU, sehr ungleichalt, Verjüngungskegel',
#   'MA   JF durch Servitutsberechtigte',
#   '',
#   ''],
#  ['128A2',
#   'ST   32, im N steiler, SS/SW',
#   'BE   Schäden durch Weidevieh, durch starken Schneebruch 2019 80% gelichtet, frischer WW, einz. AH',
#   'MA   Schadholz aufgearbeitet (Servitut)',
#   '',
#   ''],
#  ['128A3', '', '', '', '', ''],
#  ['128A4',
#   'ST   eben, Zugweg, viel Farn etwas Schlagvegetation',
#   '',
#   'BE   unglalt, 5 - 10 jg, nach N älter u dichter, geschwendet? einige AH, LA Gruppen! teils gefegt, kaum Schneeschäden, tief bekront, einz. TA; SL=',
#   'ME EE WDBI',
#   ''],
#  ['128A5', 'ST   beweidet', 'BE   Weideblöße', 'MA   zäunen und AF', '', ''],
#  ['128B1',
#   'STimNSTOE 32',
#   'BE   NH überwiegend im NW, sonst BU mit beigemischter FI',
#   'MA',
#   '',
#   ''],
#  ['128B2',
#   'ST   etwas blockig, 23/22 VTYP K',
#   'BE   unglalt, 10-25 jg, Fl teils überwachsen und von BU niedergedrückt, einz. TA/AH/WD',
#   'MA   DP, Fl von BU freistellen',
#   '',
#   ''],
#  ['128B3', '', '', '', '', ''],
#  ['125D1',
#   'ST   eben B/WS, 32/23',
#   'BE   ungleichalt, einz. FI UE, BU teils in Zwischenbestand, Schneebruch 2019',
#   'MA   Schneebruch aufgearbeitet, ZV belassen',
#   '',
#   ''],
#  ['128D2',
#   'ST   teils blockiges Gestein Übergang 23/22, etwas Schlagvegetation',
#   'BE   unglalt, einzelne UE, BU sehr Dominant, AH/TA stark verbissen, LA teils gefegt, etwas Schneedruck, SL= WD EE ME, unten älter, oben jünger',
#   'MA   ältere Teile DP',
#   '',
#   ''],
#  ['129A1',
#   'ST   steil, dicht: kaum Vegetation am Boden',
#   '',
#   'BE   vl Dürrlinge, im N jgerer Streifen, einz Alt TA, viel Totholz, ungepflegt',
#   'MA   ND LH freistellen (Anteile erhöhen) sonst belassen, ZE, 133 D',
#   'nemeınsam'],
#  ['129A2',
#   'ST   Unterhang STOE 32, Übergang zu VTYP HS',
#   'BE   ein BU/ES, S-TL 5 J jger, viel AH; Schneebruch 2019 bei Straße licht oben dicht und mehr LH, alte SS an FI, LH teils jünger',
#   'MA   DE 2010/2013, unten aufgelichtet durch Schneebruch belassen, oben DF AH Kronenpflege! (LH Brennholz)',
#   '',
#   ''],
#  ['129A3',
#   'ST   VTYP HSJB, Steig, unten STOE 32',
#   '',
#   'BE   UE = TA aus ehem Zwi-BE   ( belassen ), UE im O, einz BU, viel Schneebruch 2019, unten licht und besser oben dichter teils',
#   'unaufgearbeitet',
#   ''],
#  ['129B0',
#   'ST   VTYPSS',
#   'BE   mehrschichtig, BU AH, unglalt, vl Wipfelbrüche, Fl 91 gebohrt 53cm BHD! kaum VJ am Boden, starker Verbiss durch Reh',
#   'MA   LI (LH/TA fördern), ZE, bejagen!',
#   '',
#   ''],
#  ['129C0',
#   'ST   viel Bärlauch! beweidet',
#   'BE   SL = KB WEUL, vi Sträucher, im W-TL nur Jugend, einzelne entnommen, AH UL ES TA VJ verbissen durch Weidevieh',
#   'MA   Waldweide Trennung! ZV',
#   '',
#   ''],
#  ['129D0',
#   'ST   WS/SS',
#   'BE   zir TA-Einwüchse, vl Wipfelbrüche, TA-FI-AH Jungschicht, Horst bei STR, Reh-Fütterung',
#   'MA   unten LI, oben RM',
#   '',
#   ''],
#  ['129E1',
#   'ST   Farn, Sauerklee und etwas Brombeere',
#   'BE   TA vorw am Unterhang, Schneeschäden, Altholz ausfallend, viel Totholz',
#   'MA   Altholzentnehme! PL, ZE',
#   '',
#   ''],
#  ['129E2',
#   'BE   am Unterhang vl BU AH, einz ES, im W jger, ungleichmäßig u lückig, stabile Kronen mit Guten Zuwächsen, einz',
#   'Dürrlinge aus Zwischenbestand',
#   'MA   ab Mitte Dez. DF Kronenpflege',
#   '',
#   ''],
#  ['129E3',
#   'ST   einige Vernäsdungen',
#   'BE   ein AH BI EE BU, zT lückig dort viel Pestwurz, Fl in Gruppen, Schneebruch 2019',
#   'MA   DF oben (undurchforstet) mit Schadholz aufarbeiten',
#   '',
#   ''],
#  ['129E4',
#   'ST   32 SS/HU, einige Bäche und Vernäsdung; Traktorweg',
#   '',
#   'BE   aus Schlag 1997, s unglalt, 20-40 jg, stellenweise dichte Gruppenstruktur, starke Schneeschäden 2019 unaufgearbeitet,',
#   'frischer Einzel WW mit Käferbefall',
#   ''],
#  ['129E5',
#   'ST   2 Rinnen, Gräben VTYP HU/WS',
#   '',
#   'BE   Schneedruck 2019, ungleichalt, an den Rändern jünger, oben mehr LH, Stauden, Brombeere, unten einz TA-Reste aus vorigem',
#   'Zwi-BE, in ehemaliger Warteposition ( 40 - 70 jg), oben viel Junge TA (8j)',
#   ''],
#  ['129F1',
#   'ST   teils vernässt, viel Farn',
#   'BE   unglalt, vl Schneedruckschäden, alter nach "F2" zu abnehmend, unten vl BU AH, teils Ziel BHD bereits erreicht! Starke alte SS',
#   'MA   nächstes Dez. PL',
#   '',
#   ''],
#  ['129F2',
#   'ST   teils dicht mit nur wenig Bodenvegetation',
#   'BE   vl BU, Schneebruch 2019, teils sehr wüchsig',
#   'MA   DF ZV',
#   '',
#   ''],
#  ['129G0',
#   'ST   2 Teile, teils vernässt Farn Bach, oben alter Zugweg',
#   'BE   Artenrrich, ungleichalt (5-20j), unter STR dichter, ört! verunkrautet, Schneeschäden 2019, einz bei altem Zugweg LA!',
#   'MA   Schneeschäden entnehmen, dichte Teile durchschneiden',
#   '',
#   ''],
#  ['129HM1',
#   'ST   SS viel Brombeere',
#   '',
#   'BE   einz BU TA, s unregelmäßig bestockt, vl Wipfelbrüche, Schneebruch 2019 aufgearbeitet, Teil sehr licht, dort bereits',
#   'FI/TA Vj am Boden aufkommend',
#   ''],
#  ['129MH2',
#   'ST   Übergang SS/WS/HU Farn, Gräben',
#   '',
#   'BE   vl Schneedruckschäden, im NO 1 ha 10 J jger, einige jüngere TA/AH/BU beigemischt, TA teils Wipfelbrüche, laufend',
#   'Schadholzanfall, Ziel BHD teils bereits erreicht.',
#   ''],
#  ['129MH3',
#   'ST   sehr dicht, kaum Vegetation am Boden',
#   '',
#   'BE   im S TA-Zwi-BE-Reste, N unglalt und Schneebruch 2019 aufgearbeitet, oben unaufgearbeitet, in Mitte Schneebruchloch an Rändern',
#   'Käferbäume',
#   ''],
#  ['130A1',
#   'ST   örtl STOE 32',
#   'BE   Altholz in Zerfallsphase, stehendes Totholz, viel TA, Fl oben flächig in Vj',
#   'MA   im S RM, Rest belassen bis voll verjüngt',
#   '',
#   ''],
#  ['130A2',
#   'ST   Schlagvegetation',
#   'BE   ein FI-TA-AH-Reste aus vorigem Zwi-BE, einige ME/WD/BI/PO/UL/LA, einzelne Lücken, im O etwas Schneedruck',
#   'MA   DP 2015 erfolgt, prüfen ob Ende Dez. erneut (Artenreichtum erhalten!)',
#   '',
#   ''],
#  ['130C1',
#   'ST   kaum Vegetation am Boden',
#   'BE   unglalt, dicht, viel Schneebruch 2019 und WW',
#   'MA   DE/UE/ZV Aufarbeiten!',
#   '',
#   ''],
#  ['130C2',
#   'ST   im SSTOE 23 HU/B',
#   '',
#   'BE   vI TALA BU, bis 10 J jger bzw älter, s dicht bis weitständig bestockt, einzelne WW, Bestand teils Ziel BHD bereits',
#   'erreicht, Liefergassen',
#   ''],
#  ['130C3',
#   'ST   Rücken',
#   'BE   vI BU AH, 2 TLE, Schneebruch 2019',
#   'MA   DFZV',
#   '',
#   ''],
#  ['130C4',
#   'ST   VTYP K/HU',
#   'BE   BU/TA aus Zwi-BE-Resten, Fl teils jünger',
#   'MA   DF! + einzelne BU entnehmen',
#   '',
#   ''],
#  ['130C5',
#   'ST   Übergang zu WS/HU/B',
#   '',
#   'BE   teils jüngrr, ein AH ES BI, im N einige TA, im S von feuchtem Graben durchzogen, dort lückig; starker Schneebruch 2019 teil noch',
#   'unaufgearbeitet',
#   ''],
#  ['130D1',
#   'BE   Oberhang örtl STOE 23, viel Schlagvegetation, etwas TA mit Guten Zuwächsen leider verbissen, ME/AH/BU/WD/ES beigemischt',
#   'MAKE Tanne streichen Jagdschneise anlegen',
#   '',
#   '',
#   ''],
#  ['130D2',
#   'ST   SS etwas Farn',
#   'BE   ein AH TA, LH häufig protzig, tlw s dicht, ein Schälschäde',
#   'MA   DF/ZV AH TA freistellen, Wipfelbrüche entnehmen',
#   '',
#   ''],
#  ['130D3',
#   'BE   viel Schneebruch 2019, unten licht oben dicht, einz. AH/BU',
#   'MA   ZV Schadholz aufarbeiten, DE',
#   '',
#   '',
#   ''],
#  ['130D4',
#   'STSS',
#   'BE   aus WW 1990, Hasel unter Schirm, einz. ES, etwas Schneebruch',
#   'MA   DE Servitut!',
#   '',
#   ''],
#  ['130D5',
#   'ST   32 WS/SS',
#   'BE   2 TLE, aus Nutzung 1996, Teils bis zum Boden bekront',
#   'MA   Ende Dez. prüfen ob DE',
#   '',
#   ''],
#  ['130D6',
#   'ST   teils noch dominante Schlagvegetation, Pestwurz etwas Bingelkraut',
#   'BE   ein BU-ES-TA-AH-Reste aus vorigem Zwi-BE   ( 30-40 jg), SL= UL/BI/PO/EE/BU, viel TA Vj teils aus dem Äser teils zurückgeblieben, im N Teil TA/BU/EE durch Verbiss ausgefallen und Verhaselung',
#   'MA   dichte Teil DP, TAKE, Hasel niederschneiden',
#   '',
#   ''],
#  ['130E0',
#   'ST   Übergänge zwiscgen SS/WSJB, Oberhang seichtgründiger, ober STR ein Nassgallen',
#   '',
#   'BE   50-80 J, im O jgerer Streifen, an "A" älter, einz UL/LA, oben alte Schälschäden, absterbender Zwischenbestand,',
#   'Schneeschäden',
#   ''],
#  ['130F0',
#   'ST   eben viel Brombeere',
#   'BE   SEHR UNREGELMÄSSIG BESTOCKT; TLS WEIDEBLÖSSEN UND LIEFERGASSEN, viel AH VJ stark verbissen, nur einzeln TA VJ, Wipfelbrüche',
#   'MA   ZE nächstes Dez. LI, um VJ zu ermöglichen Rehfütterung verlegen/auflassen',
#   '',
#   ''],
#  ['131A0',
#   'ST   eben Bachbegleitend STOE 58, VTYP SS/B/HS',
#   '',
#   'BE   mehrschichtig, teils lückig teils dicht; SL=Weide, Grauerle, Ulme, ein ES, im O überwiegend mittlere AKL und Strauchschicht, im NO junge TA/FI',
#   'Gruppe von Trieblaus befallen, vl ES/TA/AH Vj unter Schirm',
#   ''],
#  ['131B1',
#   'ST   eben, viel Brombeere, VTYP SS',
#   '',
#   'BE   sehr unglalt (+-10J), im NW am jüngsten, einige ES BU AH; eine Ulme bei Bach, 2 Alttannen und viel TA/BU/AH Vj unter',
#   'Schirm',
#   ''],
#  ['131B2',
#   'ST   viel Brombeere, VTYP SS',
#   'BE   ungleichalt, vl BU WD GE ES, an STR am ältesten an Bach Vj TA/BU/AH',
#   'MA   DF: AH guter Qualität fördern',
#   '',
#   ''],
#  ['131C0',
#   'ST   eben, kleine Holzhütte bei Bach',
#   'BE   sehr unglalt, im W am ältesten, bei Bach vl BU AH ES und jger, laufend WW, einz. LA, etwas TA Vj an Forstweg',
#   'MA   ZE',
#   '',
#   ''],
#  ['131D1',
#   'ST   Bachbegleitend',
#   'BE   SL=UL WD ASPE, ein KB, sehr unterschiedlich, Altholzreste zumeist verjüngt',
#   'MA   in Straßennähe LI, FI DE',
#   '',
#   ''],
#  ['131D2',
#   'ST   eben etwas vernässt, wächst zum Teil in Bachbett ein',
#   'BE   am Bach vl WD BU, sehr unglalt, 45-70J, mehrere Wege, Ifd Schadholz, im O dicht, hoher TA Anteil',
#   'MA   dichte Teile DF, ZV',
#   '',
#   ''],
#  ['132A1',
#   'ST   neben Fluss, Forstweg',
#   'BE   vl Stäucher, alle Altersstufen vertreten, im O gut vjgt Altholzteil, SL = BU/UL/KB, Ziel DM erreichte',
#   'Bäume entnehmen, VJ/UL freistellen',
#   '',
#   ''],
#  ['132A2',
#   'ST   eben SS/B, viel Faulbaum, Erholungswald, Wanderweg',
#   'BE   3 Tle, ein AH ES, TA im mittelteil, im W 10J jger, TA ES UL EE AH VJ unter Schirm, teils Ziel DM erreicht. zahlreiche Wipfelbrüche',
#   'MA   ZV,ZN!',
#   '',
#   ''],
#  ['132A3',
#   'ST   eben etwas Schneerose',
#   'BE   ungleichalt, flächig NVJ unter Schirm, ES absterbend, viel TA einzeln auch BU/UL/LI/WD',
#   'MA   DE UL freistellen',
#   '',
#   ''],
#  ['133B0',
#   'ST   oben STOE 32, VTYP B, durch Licht Brombeere aufkommend',
#   '',
#   'BE   laufend DF, einz UL/ES, im NO mehr TA, unregelmäßig bestockt, etwas Zwischenbestand, durch Schneebruch etwas Licht. Ziel',
#   'BHD bereits erreicht! etwas AH/TA/ES NVJ am Boden',
#   ''],
#  ['133C1',
#   'ST   Unterhang STOE 41 AH, 2 Teile, oben schlechter Übergang zu 23 und Schneerosen',
#   'BE   unglalt, Blössen verstaudet',
#   'MA   KH oben mit G unten Taktor',
#   '',
#   ''],
#  ['133C2',
#   'ST   Tlober STR seichtgründiger, viel Farn',
#   '',
#   'BE   ungleichmässig bestockt, ober STR jger, sehr gutwüchsig unter Straße Ziel BHD fast schon erreicht (39cm), durch Schneeschäden',
#   'aufgelichtet',
#   ''],
#  ['133C3',
#   'ST   dicht kaum Vegetation am Boden',
#   'BE   viel Schneebruch (2019), hoher FI Anteil, viele Dürrlinge',
#   'MA   DE! ZV',
#   '',
#   ''],
#  ['133C4',
#   'ST   wenig Vegetation am Boden, Bingelkraut, Waldmeister, Goldnessel, VTYP B',
#   'BE   ein ES, oben dicht, viel Schneebruch unaufgearbeitet, ältere SS',
#   'MA   Schneebruch aufarbeiten gemeinsam mit C3 und DO, oder Holz am Waldort belassen',
#   '',
#   ''],
#  ['133C5',
#   'ST   In Blöße viel Brombeere, sonst Übergang von VTYP: SW zu HU',
#   'BE   sehr ungleichalt und in Gruppen mit einzelnrn Blößn, Esche vorwüchsig aber absterbend, einz. FI WW in älteren Teilen',
#   'MA   EG 2015, jüngere Teile DP!',
#   '',
#   ''],
#  ['133D0',
#   'ST   örtl STOE 32, oben teils auch 22 und SBS',
#   '',
#   'BE   viel AH/BU im S, vl unterständiges Material und vl Wipfelbrüche, oben dicht, schwächer und altgeschält, laufend Schadholzanfall, nach NO',
#   'lichter mit 2 Seilgassen',
#   ''],
#  ['133E1',
#   'ST   Unterhang tiefgründiger, VTYP: HS/SS/WS etwas Farn und Schlagvegetation',
#   'BE   aus KH 2015, LH/TA stark verbissen, einz. Bl und BU',
#   'MA   Bejagen!',
#   '',
#   ''],
#  ['133E2',
#   'ST   Übergang zu VTYP SL/HS, viel Hainsalat etwas Faulbaum und Bingelkraut',
#   'BE   SL=UL WEIDE KIRSCHE, im O-Tl vl Sträucher, schön geplentert!',
#   'MA   belassen ZV',
#   '',
#   ''],
#  ['133E3',
#   'BE   vi TA aus ehem ZwiBestand, vl vorwüchsige Bl, Eschensterben, Schneeschäden 2019',
#   'MA   DF AH Kronenpflege und geschädigte Fl entnehmen',
#   '',
#   '',
#   ''],
#  ['133E4',
#   'ST   etwas Schlagvegetation, Übergang von VTYP HU zu WS',
#   'BE   sehr ungleichalt 5-20j; viel LH und EE!; UEN=TA aus ehem ZwiBestand, aus Nutzung 1997, FI Vj unter Schirm!',
#   'MA   dichte jüngere Teile DP, TA-UE entnehmen, 3 als Biotopbäume belassen',
#   '',
#   ''],
#  ['133G0',
#   'ST   unten 23 oben 22 und ausgeprägte SBS VTYP',
#   'BE   am Unterhang fast reines NHM viel Totholz, hoher TA Anteil, oben viel BU und einz. UL',
#   'MA   VJ Einleiten Schlitzhieb, gemeinsam mit 134 BO, 133 DO, C1, C4 Schadholz',
#   '',
#   ''],
#  ['134A1',
#   'ST   im O-TI STOE 32 SS, 2 Teile, Schlagvegetation',
#   'BE   einz. TA UE, neben NVJ auch Hasel und Holunder, im N Blöße mit viel Brombeere',
#   'MA   im Nmit FIEG',
#   '',
#   ''],
#  ['134A2',
#   'ST   SS/SW viel Farn',
#   '',
#   'BE   einige reine LH-Horste, sehr Stammzahlreich, ES absterbend,',
#   'Wipfelbrüche und einzelner WW',
#   ''],
#  ['134A3',
#   'ST   oben STOE 32',
#   '',
#   'BE   einz TA aus vorigem ZwiBestand viel älter, gebohrt: sehr gutwüchsig! viel',
#   'Schneebruch!',
#   ''],
#  ['134A4',
#   'ST   teils vernässt mit Waldschaumkraut, teils dicht ohne Vegetation am Boden',
#   'BE   ein ES BU, einz TA aus ehem ZwiBestand, S-Tl ungleichmässig und mehr LH, einz. LI/ KB; FI flächig Schneebrüche',
#   'MA   DF/ZV AH Kronenpflege, FI Wipfelbrüche entnehmen',
#   '',
#   ''],
#  ['134B0',
#   'ST   Unterhang STOE 32, oben 22 mit VTYP SBS',
#   'BE   einz LA, unten reine FI, viel TA, LH beigemischt',
#   'MA   Schlitzhieb zur VJ Einleitung',
#   '',
#   ''],
#  ['134C0',
#   'ST   Farn einzeln Heidelbeere',
#   '',
#   'BE   im W zwischen den Zugwegen sehr gutwüchsige FI (Bon 13) und älter, mit alten SS, in der Mitte schlechter bestockt, DF 2001/2011 (Seilgassen),',
#   'im S einige ES, AH, UL, und livht durch Schnerbruch; sehr ungleich in den Dimensionen',
#   ''],
#  ['134D0',
#   'ST   Unterhang STOE 32, oben 22, vl Hangschutt',
#   'BE   viel AH, einz LA, BU und TA über Steig, Schutzwaldcharakter, oben bereits gelichtet (dort VJN), unten noch dicht',
#   'MA   ZV',
#   '',
#   ''],
#  ['134E1',
#   'ST   Übergang zu SS/SW etwas Farn und Fuchskreuzkraut',
#   'BE   Baumriesen! vereinzelt jüngere BU, zahlreiche FINVJ Kegel',
#   'MA   O Rand JF Rest belassen',
#   '',
#   ''],
#  ['134E2',
#   'ST   mäßig geneigter Hang',
#   'BE   ein BU TA ES, alt geschält, DE 2001 vorsichtig, durch Schneebruch 2019 weiter aufgelichtet',
#   'MA   belassen',
#   '',
#   ''],
#  ['134E3', '', '', '', '', ''],
#  ['134E4',
#   'ST   teils Schlagvegetation',
#   '',
#   'BE   ungleichalt 20-5j, Schneebruch bei ältere FI, LA niedergedrückt jedoch nicht ausgefallen! TA zurückgebissen einz',
#   'Zitterpappel und LI',
#   ''],
#  ['135A1', '', '', '', '', ''],
#  ['135A2',
#   'ST   flach, befahrbar etwas Farn',
#   'BE   ein Hasel, ES, viel AH NVJ, einzelne Fl VJ Kegel, AH mit teils kleiner Krone',
#   'MA   DF AH Kronen fördern',
#   '',
#   ''],
#  ['135A3',
#   'ST   Flach SS, Farn',
#   'BE   etwas ES BU TA, einzelne Schneebrüche, unter Straße mehr AH und lichter',
#   'MA   über Straße DF, unter Straße ZV',
#   '',
#   ''],
#  ['135A4',
#   'ST   vernässt, starke Rückespuren',
#   'BE   ungleichalt 10-40jg, ein LH-Gruppen, TA vIf zurückgeblieben, Einzeln TA/AH/FI UE',
#   'MA   DeEälteren Teil',
#   '',
#   ''],
#  ['135B0',
#   'ST   Grabeneinhang 35° geneigt, im N fast eben BE   am Graben vl LH einzeln UL/WD, TA teils zuruckgeblieben,',
#   'einzelne UE (AH/FI/TA)',
#   'MA   DP Mischbaumarten fördern, Stsmmzahlreduktion entfällt',
#   '',
#   ''],
#  ['135C0',
#   'ST   direkt über STR fast eben, Goldnessel Sauerklee, Feilchen SS/K, 32',
#   '',
#   'BE   stammzahlreich, viel TA AH VJ stark verbissen, sehr unglalt, unter STR jger mit vl älteren Einwüchsen und Wipfelbrüchen, laufend',
#   'durchforstet, an N Rand dichte teils schon ältere FI/BU VJ!',
#   ''],
#  ['135D1',
#   'ST   flach',
#   'BE   50-80jg, im S zir ältere Einwüchse (sehr alte TA) und mehr LH, hoher Verbissdruck auf junge TA, einz. junge LI/UL',
#   'MAZV',
#   '',
#   ''],
#  ['135D2',
#   'ST   mehrere Teile',
#   'BE   an d4 und im S jünger, dort viel LH, einige ES, im N älter und einige TA UE',
#   'MA   DF/ZV vitale AH/FI freistellen, Wipfelbrüche entnehmen',
#   '',
#   ''],
#  ['135D3',
#   'ST   etwas Waldmeister, Zwiebeltragende Zahnwurz SW/WS',
#   'BE   einz BU ESUL, ein TA-UE, teils licht, teils dichtere Gruppen',
#   'MA   2016 etwas DF, ZV',
#   '',
#   ''],
#  ['135D4',
#   'ST   etwas Waldmeister und Farn',
#   '',
#   'BE   sehr ungleichalt und innomogen, RM 1989-1992, 1994 EG, vl BU TA WD Hasel Holler,',
#   'zir AH TA UE, von W nach O jger, ein UL',
#   ''],
#  ['135F0',
#   'ST   örtl STOE 42, im SO einige Nassgallen, teils VTYP HS',
#   '',
#   'BE   einz ES BU TA im Zwischenbestand (45j), einige ältere TA, im N generell älter, unter Schirm fast flächig NVJ, stark',
#   'verbissen und verbuttet',
#   ''],
#  ['135G0',
#   'ST   viel Schlagvegetation, einz. Bingelkraut, etwas Heidelbeere, Bacheinhang',
#   '',
#   'BE   hoher LH Anteil, im W flacher, besser wüchsig, Fi teils überwachen von Himbeere und',
#   'Brombeere, im O SW und älter und einige UL',
#   ''],
#  ['136A1',
#   'ST   von 22 bis 32',
#   'BE   am Oberhang schlechter und dicht',
#   'MAAS und LI, an A3, A2 oben Gliederung',
#   '',
#   ''],
#  ['136A2',
#   'BE   unglalt 10-25jg, nach SW älter und dichter, LA vorwüchsig, vl Bl, ein BU',
#   'MA   DP LA pflegen',
#   '',
#   '',
#   ''],
#  ['136A3',
#   'ST   2 TleN-Tl flach nach NW',
#   'BE   viel LH, Fi gepflanzt',
#   'MA   DP',
#   '',
#   ''],
#  ['137A1',
#   'BE   BU vorwiegend in Mitte, oben schlecht bestockt',
#   'MA   DF 2017, oben dichter älter werden lassen',
#   '',
#   '',
#   ''],
#  ['137A2',
#   'BE   oben am Zugweg ein BU-Vorwuchsgruppen, darüber bis Grenze reine FI',
#   'MA   ende Dez. DF!',
#   '',
#   '',
#   ''],
#  ['137A3', 'MA   ende Dez. DE entlang Schlepperweg mit UE', '', '', '', ''],
#  ['137A4',
#   'BE   unten BU-reich mit BU Protzen',
#   'MA   späte DP Protzen entnehmen! LA freistellen',
#   '',
#   '',
#   ''],
#  ['137A5',
#   'BE   einz TA, im SW fast reine BU, oben reine FI, in d unteren Hälfte dichter, BU-JUWU bis 30 J',
#   'MA   DP in 2. Hälfte Dez. TA schützen',
#   '',
#   '',
#   ''],
#  ['137C0',
#   'ST   Unterhang STOE 42 SS, durch mehrere Gräben gegliedert',
#   'BE   s unterschiedlich in Bonität Bestockung u Alter, am Oberhang u an d Gräben vl BU/AH',
#   'MA   zum Teil DF 2011-2017, undurchforstet Teile vorsichtig DF, DE Charakter! max 20% entnehme',
#   '',
#   ''],
#  ['138A0',
#   'ST   Hang mit Verebngungen und Vernässungen',
#   'BE   2 TLE, unglalt, 25-35 jg, BU protzig u zurückbleibend, BU im N, oben einige vernässte Blößen',
#   'MA   DE 90 im N, DEim S',
#   '',
#   ''],
#  ['138B0',
#   'ST   Steig, WS/HS, LRV',
#   'BE   lawinengefährdet, im S noch dichtes Baumholz u kaum JUWU, einiges Totholz, z.t. Grünerlen',
#   'MA   belassen',
#   '',
#   ''],
#  ['138C0',
#   'ST   kaum Vegetation am Boden, VTYPK',
#   'BE   im SW ein BU-reicher Horst, im unteren TL vl ältere Fl, Gräben, an den Rändern mehr LH, vI Schneedruckschäde und Totholz, undurchforstet',
#   'MA   späte DF/ND durch unerschlossene Lage, nur maximal 20% entnehmen',
#   '',
#   ''],
#  ['138D0',
#   'ST   Unterhang STOE 32 oben 22, Bacheinhang',
#   'BE   ungleich in Alter, 90-110 jg, Bonität u Mischung, im O fast reine BU, vl älteres NH, im Oberhang SW! untere Teil zu FO',
#   'MA   unten bei Schlepperweg LI/JF oben belassen',
#   '',
#   ''],
#  ['138E0',
#   'ST   STOE 22/23 steil wenig Bodenvegetation',
#   'BE   ungleich in Alter, Bonität u Mischung, im O mehr BU, einz ältere TA',
#   'MA   belassen',
#   '',
#   ''],
#  ['138F0',
#   'ST   Unterhang STOE 32',
#   '',
#   'BE   ungleich in Alter und Mischung, im W mehr LH (AH/BU), vl älteres NH und Totholz, ein Rücken gelichtet und vetjüngt',
#   'teils Schneedruckschäden',
#   ''],
#  ['139A1',
#   'BE   vl ER, einige Lücken, im oberen TL überaltes NH',
#   'MA   belassen',
#   '',
#   '',
#   ''],
#  ['139A2', 'BE   Seilnutzung 2010 Käfer', 'MA   DE 90 mit 138 AO', '', '', ''],
#  ['139C0',
#   'ST   am Grat Steig, sehr steil und Bodenerosion',
#   'BE   vl AH, TA etw BU/FI-VJG, vl Dürrlinge, einige besser bestockte Partien, einz. ME/EE',
#   'MA   Bestockung belassen',
#   '',
#   ''],
#  ['141B0',
#   'ST   von mehreren Rinnen durchzogen, lawinengefährdet, Steilabbruch, SW Charakter',
#   'BE   NH im NW u SO, LH d mittleren AKL im NO, unten etwas lückig, ober C5 belassen',
#   'MA   bergab Seilung LI, ZE',
#   '',
#   ''],
#  ['141C1',
#   'ST   am Unterhang STOE 42 AH, oben STOE 23, beweidet',
#   'BE   2 TLE, einz BU, Unterhang flach u gutwüchsig, örtl gelichtet, und mit guter FI/TA NVJ',
#   'MA   nach gesicherter VJ in C5 O-Teil RM, JF entlang Forstweg',
#   '',
#   ''],
#  ['141C2',
#   'ST   oben 23',
#   'BE   Schäden durch Weidevieh, NO-TL vi AH, gutwüchsig',
#   'MA   DE beide Teile gemeinsam Bergabseilung!',
#   '',
#   ''],
#  ['141C3',
#   'ST   beweidet',
#   'BE   unglalt, 5-25 jg, ein EE Bl, einz Lücken, ein Reste aus vorigem Zwi-BE, oben jünger und Schneedruckschäden, LH teils jünger',
#   'MA   DP 2013/2019, Schneedruck niederschneiden TA fördern',
#   '',
#   ''],
#  ['141C4', 'MA   oberer Teil DP', '', '', '', ''],
#  ['142A1',
#   'ST   beweidet Wanderweg eben',
#   'BE   3 TLE, unglalt u ungleichmäßig bestockt, an Rändern und im N NVJ',
#   'MA   AD/JF/RM',
#   '',
#   ''],
#  ['142A2',
#   'ST   mehrere Teile teils an Straße',
#   'BE   ein TA, unglalt, 30-50 jg u ungleichmäßig bestockt, WW-geschädigt, lückig bis dicht',
#   'MA   an Straße einz. DF',
#   '',
#   ''],
#  ['142A3',
#   'ST   teils neben neuem Forstweg',
#   'BE   2 TLE, im SW Zwi-BE-Reste, Schneebruch 2019',
#   'MA   ZV sonst belassen',
#   '',
#   ''],
#  ['142A4',
#   'ST2 TLE, SW',
#   'BE   ein TA AH BI ES WE, im N-TL mehr LH u BU-Reste aus vorigem Zwi-BE, starker Schneebruch 2019',
#   'MA   DE/ZV',
#   '',
#   ''],
#  ['142A5',
#   'ST   unter Straße, einige Vernässungen, Traktorweg',
#   'BE   vl EEE, ein BU, einz Bl, im N lückig mit einz TA',
#   'MA   AH Wertasten',
#   '',
#   ''],
#  ['142A6',
#   'BE2TLE, vl EE, ein AH, einz Reste aus vorigem Zwi-BE, etw lückig, tief bekront',
#   'MA   DP 2018 Belassen',
#   '',
#   '',
#   ''],
#  ['143A0',
#   'BE   s unglalt, 15-50 jg, in d Mitte ober STR am jgsten, unter STR an Bach etwas WE/ER, Angrenzend an BO ältere BU/TA, im N älterer TL, viel',
#   'UL, und einz jüngere TA, im NO lückig mit LH-NVJG,',
#   'MA   DF LH guter Qualität und TA freistellen',
#   '',
#   ''],
#  ['143B0',
#   'ST   eben, zir Nassgallen, im O STOE 23 , HS/AH',
#   'BE   unglalt, einz ES/GE, im O jger, vl TA VJ unter Schirm',
#   'MA   ZV nächstes Dez LI',
#   '',
#   ''],
#  ['143D1',
#   'BE   unglalt, 25-40 jg, vl ältere Einwüchse, s ungleichmäßig, etwas UL und Hasel, Bach',
#   'MA   DF Dr2',
#   '',
#   '',
#   ''],
#  ['143D2',
#   'ST   Bach, Schlepperweg',
#   'BE   ein BU ES EE, TA von Trieblaus am Stamm befallen, Teil dicht und ungepflegt',
#   'MA   DF! TA/LH gördern',
#   '',
#   ''],
#  ['143D3',
#   'ST   eben, Tannentrieblaus am Stamm',
#   '',
#   'BE   ein BU BI EE, AH vor allem im S-TL, dort NH häufig zurückbleibend, s unglalt, 20-36 jg, einz ältere BU/AH, TA teils schwächer Dimensioniert und im',
#   'Zwischenbestand, Tannenkrebs',
#   ''],
#  ['143D4',
#   'ST   leicht geneigter Hang',
#   'BE   einz BU-Reste aus vorigem Neben-BE, vl BI EE, sehr unglalt, jüngere Teile stark Schneedruck und Bruch geschädigt, erfreulich hoher TA Anteil',
#   'MA   DP nicht überall durchgeführt, DE 90 TA fördern, Schneedruck niederschneiden',
#   '',
#   ''],
#  ['143E1',
#   'E unglalt, im S mehr TA u zT weitständig, flächig VJ mit hohem TA Anteil, teils älter (in Mitte), im N unverjüngt und vl Totholz',
#   'MA   RM ende Dez.',
#   '',
#   '',
#   ''],
#  ['143E2',
#   'BE   ein BU AH EE, im S von Wiese 1997 SR u 5 J älter, über STR 5 J jger, im N zu Bach lückig (alte Wiese ), im N mehr LH',
#   'MA   DE Servitutsholz (18+ BHD) händisch, älteren vor jüngerem, TA/AH fördern',
#   '',
#   '',
#   ''],
#  ['143E3',
#   'ST   Rehfütterung, ebener Rücken',
#   'BE   unglalt, 5-15 jg, vl BI EE, TA gestrichen',
#   'MA   DP 2013, ende Dez Kontrolle ob DE',
#   '',
#   ''],
#  ['143E4',
#   'BE   einz BU, an Rändern älter; s unglalt, im N älterer TL, einz Reste aus vorigem Zwi-BE, jüngeres stark Schneedruck 2019',
#   'geschädigt',
#   'MA   junge Teile bei Straße DP',
#   '',
#   '']]

# %%
data.wo_data
# Out:
# [['094B1', 0, 0, 23, '', 0],
#  ['094B2', 0, 0, 0, '', 0],
#  ['094D1', 0, 0, 0, '', '2'],
#  ['094D2', 0, 0, 0, 'HS', 0],
#  ['094D3', 0, 0, 0, 'SS', 0],
#  ['094D4', 0, 0, 0, 'SS', 0],
#  ['094D5', 0, 0, 0, '', 0],
#  ['094D6', 0, 0, 0, 'SS', 0],
#  ['094G0', 0, 0, 0, '', 0],
#  ['094I0', 0, 0, 0, '', 0],
#  ['094K1', 0, 0, 0, '', 0],
#  ['094K2', 0, 0, 0, '', 0],
#  ['094K3', 0, 0, 0, 'WS', 0],
#  ['094K4', 0, 0, 22, 'BH', 0],
#  ['094K5', 0, 0, 22, 'BH', 0],
#  ['094K6', 0, 0, 0, 'ws', 0],
#  ['094L1', 0, 0, 0, '', 0],
#  ['094L2', 0, 0, 0, '', 0],
#  ['094M1', 0, 0, 0, '', 0]]

# %%
# get SAP raw data

# %%
# set raw_path
raw_path = os.path.join(home_path, 'Data', 'obf_autman', 'raw_data', 'TO_1364_178_02_20201111.XLS')
# read tsv
wo_data = pd.read_csv(raw_path, sep='\t', encoding = "ISO-8859-1", decimal=',', error_bad_lines=False)
# filter relevant data
wo_data = wo_data[wo_data['Best.-Schicht'] == 0]

### pernitz
wo_data = wo_data[wo_data['Abteilung'] > 93]

# sort data
wo_data.sort_values(by=['Abteilung', 'WE-Typ', 'Unterabteil.', 'Teilfl.'], ascending=[True,False,True,True], inplace=True)
wo_data = wo_data[['Waldort', 'WE-Typ']]

# %% [markdown]
# ### write to disk

# %%
# loop over all data
for data_part in [[data.wo_data, 'wo_data', ['Waldort', 'bkl', 'uz', 'stoe', 'vtyp', 'vg']], \
                  [data.bz, 'bz', ['Waldort', 'BZ1', 'BZ2', 'BZ3', 'BZ4', 'BZ5']], \
                  [data.text, 'text', ['Waldort', 'text1', 'text2', 'text3', 'text4', 'text5']], \
                  [data.ma, 'ma', ['Waldort', 'S1', 'MA1', 'fl1', 'DR1', 'BH1', 'ZP1', 'SG1', 'RU1', 'Text1',\
                                   'S2', 'MA2', 'fl2', 'DR2', 'BH2', 'ZP2', 'SG2', 'RU2', 'Text2',\
                                   'S3', 'MA3', 'fl3', 'DR3', 'BH3', 'ZP3', 'SG3', 'RU3', 'Text3']]]:
    
    print('creating ' + data_part[1])
    
    # create a dataframe out of the list
    df = pd.DataFrame(data_part[0], columns=data_part[2])

    # merge
    merge_data = pd.merge(wo_data, df, how='left', on='Waldort')

    # specify the path for writing dow the data
    save_path = os.path.join(home_path, 'Data', 'obf_autman', 'csv', 'feistenau', data_part[1] + '_1364_02.csv')
    # write data to disk
    df.to_csv(save_path, index=False)
# Out:
# creating wo_data
# creating bz
# creating text
# creating ma
